# %%
# pip install apyori
# pip install efficient-apriori
# pip install mlxtend

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import fpgrowth, apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
# from efficient_apriori import apriori

# %%
free -h
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [215], in <cell line: 1>()
# ----> 1 free -h
#
# NameError: name 'free' is not defined

# %%
instacart = pd.read_csv('../data/instacart.csv')
instacart.drop('Unnamed: 0', axis = 1, inplace=True)
print('Dataset shape:', instacart.shape)
instacart.head()
# Out:
# Dataset shape: (21407642, 14)
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2   202279             3          5                  9
# 1         2   202279             3          5                  9
# 2         2   202279             3          5                  9
# 3         2   202279             3          5                  9
# 4         2   202279             3          5                  9
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     8.0       28985                  2          1
# 1                     8.0        9327                  3          0
# 2                     8.0       30035                  5          0
# 3                     8.0       17794                  6          1
# 4                     8.0        1819                  8          1
#
#                                product_name  department_id  aisle_id  \
# 0                     Michigan Organic Kale              4      83.0
# 1                             Garlic Powder             13     104.0
# 2                         Natural Sweetener             13      17.0
# 3                                   Carrots              4      83.0
# 4  All Natural No Stir Creamy Almond Butter             13      88.0
#
#                 aisle department
# 0    fresh vegetables    produce
# 1   spices seasonings     pantry
# 2  baking ingredients     pantry
# 3    fresh vegetables    produce
# 4             spreads     pantry

# %% [markdown]
# There are more than 21 millions of orders. I am going to select the orders of 2 million of users to reduce the size of the data.

# %%
order_set = instacart.iloc[:2000000, :]
order_set.head()
order_set['order_id'].max()
# Out:
# 319928

# %% [markdown]
# Now we have around 320.000 orders.

# %%
prods = order_set[['order_id', 'product_name']].reset_index(drop=True)
prods.sort_values(by='order_id')
# Out:
#          order_id                                       product_name
# 0               2                              Michigan Organic Kale
# 1               2                                      Garlic Powder
# 2               2                                  Natural Sweetener
# 3               2                                            Carrots
# 4               2           All Natural No Stir Creamy Almond Butter
# ...           ...                                                ...
# 1999995    319927                                     Instant Coffee
# 1999998    319928                              Organic D'Anjou Pears
# 1999996    319928                                    Chopped Walnuts
# 1999997    319928  Happy Tot Banana, Peach, Prune & Coconut Organ...
# 1999999    319928                               Creamy Almond Butter
#
# [2000000 rows x 2 columns]

# %%
prods['product_name'] = prods['product_name'].apply(lambda x: x.lower())
prods['product_name'].head()
# Out:
# 0                       michigan organic kale
# 1                               garlic powder
# 2                           natural sweetener
# 3                                     carrots
# 4    all natural no stir creamy almond butter
# Name: product_name, dtype: object

# %%
order_num = prods['order_id'].unique()
prod_lst = []

for v,num in enumerate(order_num):
    products = prods.loc[prods['order_id'] == num]['product_name'].tolist()
    prod_lst.append(products)

# %%
basket = pd.DataFrame(order_num, columns = ['num_order'])
basket.head()
# Out:
#    num_order
# 0          2
# 1          3
# 2          4
# 3          5
# 4          6

# %%
basket['products_ordered'] = [lst for lst in prod_lst]
basket
# Out:
#         num_order                                   products_ordered
# 0               2  [michigan organic kale, garlic powder, natural...
# 1               3  [unsweetened chocolate almond breeze almond mi...
# 2               4  [original orange juice, kellogg's nutri-grain ...
# 3               5  [organic raspberries, clementines, natural art...
# 4               6                      [dryer sheets geranium scent]
# ...           ...                                                ...
# 292760     319924  [strawberries, roma tomato, brown large eggs g...
# 292761     319925  [garlic mint cheese, bolani spinach filled fla...
# 292762     319926  [yellow onions, towelettes, make up removing, ...
# 292763     319927                                   [instant coffee]
# 292764     319928  [chopped walnuts, happy tot banana, peach, pru...
#
# [292765 rows x 2 columns]

# %% [markdown]
# #### Filter rows were products ordered = or bigger than 2 to find associations

# %%
selection = [elem for elem in basket['products_ordered'] if len(elem) >= 1]
selection
# Out:
# [['michigan organic kale',
#   'garlic powder',
#   'natural sweetener',
#   'carrots',
#   'all natural no stir creamy almond butter'],
#  ['unsweetened chocolate almond breeze almond milk',
#   'unsweetened almondmilk',
#   'organic ezekiel 49 bread cinnamon raisin',
#   'lemons',
#   'air chilled organic boneless skinless chicken breasts',
#   'organic baby spinach'],
#  ['original orange juice',
#   "kellogg's nutri-grain apple cinnamon cereal",
#   'goldfish cheddar baked snack crackers',
#   'honey/lemon cough drops',
#   'sugarfree energy drink',
#   "kellogg's nutri-grain blueberry cereal",
#   'oats & chocolate chewy bars',
#   'nutri-grain soft baked strawberry cereal breakfast bars'],
#  ['organic raspberries',
#   'clementines',
#   'natural artesian water, mini & mobile',
#   'mini original babybel cheese',
#   'dairy milk fruit & nut chocolate bar',
#   'boneless skinless chicken breast fillets',
#   'wafer, chocolate',
#   'matzos, thin, tea',
#   'original black box tablewater cracker',
#   'french lavender hand wash',
#   'just crisp, parmesan',
#   'apricot preserves',
#   '2% reduced fat milk',
#   'bag of organic bananas'],
#  ['dryer sheets geranium scent'],
#  ['original hawaiian sweet rolls'],
#  ['baby spinach',
#   'low fat kefir cultured milk smoothie lowfat probiotic blueberry',
#   'natural sharp cheddar sliced cheese',
#   'snak-saks crackers',
#   'fruit & nutty almonds raisins cranberries pecans granola',
#   'distilled water',
#   'organic red radish, bunch',
#   'vanilla almond breeze almond milk',
#   '100% apple juice original',
#   'organic bread with 21 whole grains',
#   'green beans',
#   'extra virgin olive oil'],
#  ['boneless beef sirloin steak',
#   'organic strawberries',
#   'organic cilantro',
#   'yellow onions',
#   'green beans',
#   'organic black beans',
#   'organic sunchoke',
#   'stage 2 green bean pear greek yogurt baby food',
#   'parsley, italian (flat), new england grown',
#   'banana',
#   'organic butterhead (boston, butter, bibb) lettuce',
#   'baby portabella mushrooms'],
#  ['teriyaki & pineapple chicken meatballs',
#   'extra virgin olive oil',
#   'mango pineapple salsa',
#   'traditional refried beans',
#   'tortilla strips restaurant style'],
#  ['100% juice no sugar added apple',
#   '2% milk',
#   'game day barbecue trail mix',
#   'chocolate caramel cashew trail mix',
#   'sweet & salty snack mix',
#   'combination pizza rolls',
#   'french vanilla coffee creamer',
#   '100% juice no added sugar orange tangerine'],
#  ['hampshire 100% natural sour cream',
#   'lemon lime thirst quencher',
#   'diet tonic water',
#   'chunky salsa medium',
#   'light',
#   'soda',
#   'original potato chips',
#   'g series lime cucumber sports drink'],
#  ['unprocessed american singles colby-style cheese',
#   'organic mini homestyle waffles',
#   'organic broccoli florets',
#   'naturals chicken nuggets',
#   'sriracha chili sauce',
#   'organic whole milk',
#   'corn meal pizza crust',
#   'hair bender whole bean coffee'],
#  ['spring water',
#   'organic extra virgin olive oil',
#   'honeysuckle hand soap',
#   'pinto beans no salt added',
#   'olive oil & aloe vera hand soap'],
#  ['original popcorn', 'water'],
#  ['cilantro pesto',
#   'organic fiber & protein pear blueberry & spinach baby food',
#   'raspberry preserves',
#   'organic unsalted butter',
#   'basil, asiago & pine nut pesto ravioli',
#   'watermelon chunks',
#   'organic maple & onion baked beans',
#   'organic raspberries',
#   'organic hazelnut spread',
#   'pitted prunes',
#   'sesame oil, pure',
#   'frozen broccoli florets',
#   '100% recycled paper towels',
#   'sweet corn on the cob',
#   'apricots',
#   'ataulfo mango',
#   'balsamic reduction traditional balsamic'],
#  ['unsweetened almondmilk'],
#  ["danimals swingin' strawberry banana smoothie",
#   'banana',
#   'oven baked original potato chips',
#   'sweet red grape tomatoes'],
#  ['yuba tofu skin',
#   'dairy-free cheddar style wedges',
#   'cold brew coffee',
#   'frozen organic blueberries'],
#  ['2% reduced fat milk',
#   'iceberg lettuce',
#   'large grade aa eggs',
#   'banana',
#   'sandwich bags',
#   'boneless and skinless chicken breast',
#   'deli fresh honey smoked turkey breast, 98% fat free, gluten free',
#   'presliced everything bagels',
#   'butter top white bread'],
#  ['organic red onion',
#   '34% cacao milk chocolate bar',
#   'potato yukon gold organic',
#   'gluten and dairy free sonoma veggie burger',
#   'white corn',
#   'dairy-free chive cream cheese',
#   'gluten-free supergrain pasta organic corn & quinoa blend penne',
#   'lime',
#   'fluoride-free antiplaque & whitening spearmint toothpaste',
#   'organic baby spinach salad'],
#  ['mint chocolate cookie ice cream'],
#  ['all whites 100% egg whites',
#   'delights turkey sausage egg whites & cheese english muffin',
#   'ultra thin sliced provolone cheese',
#   'cheese shredded mozzarella reduced fat 2%',
#   'original popcorn',
#   'craveables four cheese pizza',
#   'macaroni and cheese',
#   'boomchickapop sweet & salty kettle corn'],
#  ['boneless skinless chicken breasts', 'banana', 'organic baby spinach'],
#  ['organic marinara pasta sauce',
#   'teriyaki veggie burgers',
#   'organic no salt added diced tomatoes',
#   'organic mango chunks',
#   'michigan organic kale',
#   'pasta joy ready organic brown rice pasta penne',
#   'parchment paper',
#   'carrots',
#   'organic whole strawberries',
#   'lemon hummus',
#   'almond meal/flour',
#   'green bell pepper',
#   'no salt added black beans',
#   'organic low sodium vegetable broth',
#   'coconut sugar pure & unrefined',
#   'roasted red pepper hummus',
#   '3 lb clementines',
#   'bag of organic bananas',
#   'low fat vanilla yogurt',
#   'organic eggplant'],
#  ['large greenhouse tomato',
#   "organic d'anjou pears",
#   'organic red delicious apple',
#   'cultured low fat buttermilk',
#   'air chilled organic boneless skinless chicken breasts',
#   'original semisoft cheese',
#   '1% lowfat milk',
#   'organic heavy whipping cream'],
#  ['smartwater', 'bag of organic bananas', 'baby cucumbers'],
#  ['mango chunks'],
#  ['organic cilantro',
#   'heirloom tomato',
#   'organic yellow onion',
#   'organic baby spinach',
#   'organic vidalia onion',
#   'roasted & salted almonds',
#   'seedless red grapes'],
#  ['organic broccoli florets',
#   'organic bread with 21 whole grains',
#   'lactose free grade a low fat vanilla yogurt',
#   'clementines, bag',
#   'organic lactose free 1% lowfat milk',
#   'bag of organic bananas',
#   'seedless red grapes'],
#  ['organic olive oil  spray',
#   'cold-brew black coffee',
#   'gourmet mochi ice cream vanilla bonbons',
#   'kale, apple, ginger, romaine, spinach, cucumber, celery, parsley, lemon cold pressed juice beverage',
#   'gluten free mushroom risotto bowl'],
#  ['coconut water',
#   'sea salt brown rice crackers',
#   'bunny-luv organic carrots',
#   'cranberry almond chicken salad'],
#  ['sliced genoa salami',
#   'organic baby spinach',
#   'yellow onions',
#   'organic fuji apple'],
#  ['organic 1% low fat milk'],
#  ['all natural seasoned waffle cut fries', 'uncured genoa salami'],
#  ['unsweetened vanilla almond breeze', 'bag of organic bananas'],
#  ['white cheddar semisoft cheese',
#   'lowfat 2% milkfat cottage cheese',
#   'mozzarella light low moisture part skim string cheese',
#   'original denture adhesive cream',
#   '13 gallon kitchen drawstring trash bags'],
#  ['eggo nutri-grain blueberry waffles',
#   'diet mountain dew soda',
#   'clover honey bear',
#   'presliced everything bagels',
#   'sausage biscuit',
#   'french onion dip',
#   'breaded chicken breast tenders',
#   'chicken pot pie',
#   'cereal'],
#  ['organic yams'],
#  ['reduced fat original potato crisps',
#   "thick 'n creamy macaroni & cheese",
#   '90 calories low fat chocolate chunk granola bars',
#   'ultra soft bathroom tissue, double rolls',
#   '100% whole wheat bread',
#   'reduced sugar mixed fruit fruit snacks',
#   'reduced fat sliced provolone cheese',
#   'chicken marsala',
#   'original',
#   'light sour cream',
#   "berries 'n cherries fruit snacks",
#   'wheat thins reduced fat crackers',
#   'simply 100 strawberry blended non-fat greek yogurt',
#   'plates, 10-1/16 inch'],
#  ['golden pineapple', 'strawberries'],
#  ['yo baby organic whole milk banana mango yogurt',
#   'yokids squeezers organic low-fat yogurt, strawberry',
#   'original barbeque sauce',
#   'gluten-free chicken nuggets',
#   'low sodium beef broth',
#   'organic chicken bone broth'],
#  ['organic blueberry', 'original pure creamy almond milk', 'single origin 3'],
#  ['organic fresh basil',
#   'french vanilla ice cream',
#   'peach yoghurt',
#   'shredded parmesan',
#   'pure granulated cane sugar'],
#  ['milk whole',
#   'baby dynamic duo potatoes',
#   'organic extra virgin olive oil',
#   'cookie sheets',
#   'italian sparkling pomegranate and orange soda',
#   'artesano style bread',
#   'acorn squash'],
#  ['cinnamon raisin granola', 'banana', 'apple cider vinegar'],
#  ['organic lemon',
#   'organic original tofu veggie burger',
#   'sweet baguette',
#   'yo baby organic whole milk banana mango yogurt',
#   'banana'],
#  ['banana',
#   'sliced peaches',
#   'original whipped topping',
#   'instant french vanilla pudding & pie filling'],
#  ['total 2% lowfat plain greek yogurt',
#   'blood oranges',
#   'organic braeburn apple',
#   'bag of organic bananas',
#   'organic butterhead (boston, butter, bibb) lettuce',
#   'root + hair deep repair conditioning hair mask',
#   'organic cucumber',
#   'spaghetti',
#   'organic lemon',
#   'organic red onion',
#   'large alfresco eggs',
#   'semi-sweet chocolate premium baking chips',
#   'organic spinach bunch',
#   'organic large green asparagus',
#   'italian sausage pizza',
#   'roasted mushroom pizza',
#   'organic raspberries'],
#  ['large alfresco eggs',
#   'organic garlic',
#   'shredded parmesan',
#   'coconut almond creamer blend',
#   'blueberries',
#   'buttermilk biscuits',
#   'organic baby spinach',
#   'organic tomato paste'],
#  ['organic large extra fancy fuji apple',
#   'organic baby spinach',
#   'organic strawberries'],
#  ["organic d'anjou pears",
#   'organic original hommus',
#   'marinara sauce',
#   'bag of organic bananas',
#   'organic blackberries'],
#  ['prepared meals simmered chicken medley wet dog food',
#   'prepared meals beef stew wet dog food'],
#  ['carrots',
#   'organic yellow onion',
#   'organic australian style vanilla lowfat yogurt',
#   'bag of organic bananas',
#   'organic honeydew',
#   'organic diced tomatoes',
#   'tomato sauce',
#   'organic roasted turkey breast',
#   'muffins, mini, flax, chocolate brownie',
#   'skim milk',
#   'organic shredded mild cheddar',
#   'organic raspberries'],
#  ['frozen organic blueberries',
#   'organic low fat milk',
#   'non fat greek yogurt',
#   'clementines',
#   'premium grapefruit large',
#   'original almondmilk',
#   'dairy free unsweetened coconut milk',
#   'sea salt brown rice crackers',
#   'with crispy almonds cereal',
#   'half and half cream'],
#  ['no salt added black beans', 'jalapeno peppers', 'tilapia filet', 'limes'],
#  ['red potatoes',
#   'turkey',
#   'wild blend rice',
#   'red bell pepper',
#   'boneless skinless chicken breast',
#   'whole grain oatmeal bread',
#   'garlic powder'],
#  ['purified water',
#   'ultra soft & strongâ® toilet paper double rolls',
#   'caramel vanilla cream light roast k-cup packs arabica coffee',
#   'half and half ultra pasteurized'],
#  ['organic 2% reduced fat milk', 'organic 1% lowfat milk', 'soy sauce'],
#  ['soft baked chocolate chip cookies gluten free',
#   'organic lightly salted sea salt thin & crispy restaurant style tortilla chips',
#   'all natural marinara pasta sauce'],
#  ['plain greek yogurt',
#   'bag of organic bananas',
#   'prosciutto',
#   'high pulp orange juice',
#   'maple glazed honey ham'],
#  ['migraine caplets',
#   'soda',
#   'blackberries',
#   'seltzer water',
#   'ginger dressing',
#   'non fat greek yogurt',
#   'gourmet tomato medley',
#   'granny smith apples'],
#  ['stage 2 spinach, apple & kale',
#   'baby food pouch - butternut squash, carrot & chickpea',
#   'organic romaine leaf',
#   'organic whole milk',
#   'chocolate peanut butter cup gelato',
#   'hass avocados'],
#  ['organic quinoa & brown rice with garlic', '100% whole wheat hot dog buns'],
#  ['toasted coconut chips original recipe',
#   'organic lemon',
#   'tilapia filet',
#   'organic cilantro',
#   'limes',
#   'fresh ginger root'],
#  ['organic homogenized whole milk',
#   'original traditional dijon mustard',
#   'organic fuji apple',
#   'vegan buttery sticks',
#   'toasted coconut almondmilk blend',
#   'banana'],
#  ['olive bread',
#   'bunny-luv organic carrots',
#   'organic baby spinach',
#   'organic simply naked pita chips'],
#  ['organic low sodium chicken cooking stock',
#   'organic mayonnaise',
#   'organic sunday bacon',
#   'original soy creamer',
#   'organic beefsteak tomato',
#   'organic chicken bone broth',
#   'rosemary ham',
#   'liquid egg whites',
#   'organic roma tomato'],
#  ['organic short brown sprouted rice',
#   'organic baby arugula',
#   'mint chip',
#   'organic plain greek whole milk yogurt',
#   'roasted red pepper hummus',
#   'four cheese thin crust pizza',
#   'gum ginger',
#   'roasted garlic loaf',
#   'hass avocados'],
#  ['cinnamon sugar cookie chips', 'seedless watermelon'],
#  ['red peppers',
#   'orange bell pepper',
#   'organic cucumber',
#   'organic yellow onion',
#   'yellow bell pepper',
#   'veggie burger, quarter pound',
#   'organic vanilla soymilk',
#   'sea salt pita chips',
#   'california sourdough bread',
#   'apple honeycrisp organic',
#   'beyond beef beefy crumble'],
#  ['fresh mozzarella all-natural sliced cheese',
#   'whole grain cheddar baked snack crackers',
#   'fat free skim milk',
#   'roasted pine nut hummus',
#   'strawberries'],
#  ['sponge scrubber - 3 ct',
#   'english breakfast tea bags',
#   'original magic eraser',
#   'cozy chamomile herbal tea',
#   'whole milk',
#   'bag of oranges',
#   'earl grey tea bags'],
#  ['organic whole milk',
#   'yellow bell pepper',
#   'organic yokids lemonade/blueberry variety pack yogurt squeezers tubes',
#   'organic blackberries',
#   'sour cream',
#   'banana'],
#  ['canary melon',
#   'unsweetened almondmilk',
#   'organic baby spinach salad',
#   'organic english cucumber',
#   'organic strawberries',
#   'organic acorn squash'],
#  ['organic beef uncured hot dogs',
#   'organic whole kernel sweet corn no salt added',
#   'strawberries',
#   'premium traditional homestyle cream style corn',
#   'mild diced green chiles'],
#  ['toasted coconut chips original recipe',
#   'juice beverage, cold pressed, kale apple ginger romaine spinach cucumber celery parsley lemon',
#   'sunrise crunchy cinnamon cereal',
#   'bag of organic bananas',
#   'yellow onions',
#   'large pineapple chunks',
#   'original bbq sauce',
#   'cheese ravioli',
#   'light & lean black bean and cheese enchilada'],
#  ['organic mint',
#   'mango coconut chia squeeze',
#   'bunched cilantro',
#   'chai green tea bags 16 count',
#   'organic milk',
#   'ancient grain blueberry hemp granola'],
#  ['mini marshmallows',
#   'miniatures',
#   'green seedless grapes',
#   'strawberries',
#   'red globe grapes'],
#  ['dha omega 3 vitamin d milk',
#   'disinfecting multi-surface cleaner lemongrass citrus scent',
#   'organic whole grain wheat english muffins',
#   'natural free & clear dishwasher detergent packs'],
#  ['strawberries',
#   'cantaloupe grapefruit sparkling water',
#   'completeâ„¢ actionpacsâ„¢ fresh scent dishwasher detergent',
#   'honey mustard dressing topping & spread',
#   'salt & vinegar potato chips',
#   'ion4 mountain berry blast',
#   'original fresh stack crackers'],
#  ['baby seedless cucumbers',
#   'iceberg lettuce',
#   'low fat vanilla yogurt',
#   'banana',
#   'organic strawberries',
#   'penne rigate #41 pasta',
#   'original semisoft cheese',
#   'mango chunks',
#   'apple cinnamon gogo squeez',
#   'plus cranberry almond + antioxidants with macadamia nuts bar',
#   'atlantic salmon fillets',
#   'organic baby arugula',
#   'garlic hummus',
#   'half and half',
#   'total 2% all natural greek strained yogurt with honey'],
#  ['sweet & salty kettlecorn', 'carrots', 'organic lemon', 'ataulfo mango'],
#  ['organic diced tomatoes', 'organic whole peeled tomatoes'],
#  ['quinoa & leeks with chicken + tarragon organic baby food',
#   'organic avocados',
#   'organic celery'],
#  ['medium salsa organica',
#   'sea salt potato chips',
#   'wild berry smoothie',
#   'banana',
#   'organic strawberries',
#   'organic yellow mustard',
#   'buttermilk biscuits',
#   'organic blackberries',
#   'coconut aminos teriyaki sauce',
#   'chopped onions',
#   'organic beefsteak tomato',
#   'organic baby spinach',
#   'organic turkey bacon',
#   'organic toaster pastries frosted lotta chocolotta - 6 ct',
#   'organic hass avocado bag'],
#  ['37% less sodium soy sauce',
#   'bag of organic bananas',
#   'roma tomato',
#   'sweetened corn & oat cereal',
#   'delifresh combos the honey smoked turkey breast honey ham',
#   'chewy granola bars variety pack',
#   '2% reduced fat milk',
#   'pure & natural sour cream'],
#  ['large alfresco eggs',
#   'walnut halves & pieces',
#   'frozen organic wild blueberries'],
#  ['organic free range large grade a brown eggs',
#   'organic whole string cheese',
#   'hickory smoked ham',
#   'plain goat milk yogurt',
#   'organic strawberries',
#   'wild sockeye salmon',
#   'purity farms ghee clarified butter'],
#  ['3 minute miracle moist deep conditioning treatment',
#   'icelandic style skyr blueberry non-fat yogurt',
#   'chocolate chip cookie dough ice cream',
#   'shampoo, body wash, bubble bath coconut+lemon',
#   'yokids squeezers organic low-fat yogurt, strawberry',
#   'organic yokids lemonade/blueberry variety pack yogurt squeezers tubes',
#   'bagel thins everything',
#   'organic yokids smoothie strawberry banana lowfat yogurt',
#   'uncured slow cooked ham',
#   'oil-free acne wash',
#   'moroccan argan oil renewing shampoo',
#   'multi-grain sea salt crackers',
#   'hazelnut spread with skim milk & cocoa',
#   'chicken apple sausage egg white breakfast burrito',
#   'french roast ground coffee'],
#  ['uncured beef hot dogs',
#   'tamari gluten free soy sauce reduced sodium',
#   'hearty style 100% whole grain whole wheat bread',
#   'fully cooked maple sausages 10 count'],
#  ['spring water', 'soda'],
#  ['lemon italian sparkling mineral water',
#   'vidalia onion and cilantro dressing marinade',
#   'mini cucumbers',
#   'flat fillets of anchovies',
#   'sea salt popcorn',
#   'organic baby arugula',
#   'toasted coconut almondmilk blend',
#   'organic fresh carrot chips'],
#  ['roma tomato',
#   'rice thins brown rice snack crackers',
#   'organic raspberries',
#   'fresh cauliflower',
#   'thick & chunky salsa',
#   'organic romaine'],
#  ["major dickason's blend ground coffee dark roast",
#   'french roast ground coffee',
#   'house blend deep roast ground coffee'],
#  ['organic blackberries',
#   'total 0% raspberry yogurt',
#   'oven roasted turkey',
#   'watermelon chunks'],
#  ['chocolate chip cookie dough ice cream',
#   'organic fuji apple',
#   'whole milk',
#   'organic appleapple',
#   'apple cinnamon gogo squeez',
#   'natural artisan water',
#   'real aged cheddar macaroni & cheese',
#   'yokids squeezers organic low-fat yogurt, strawberry',
#   'bag of organic bananas',
#   'cage free large white eggs',
#   'seedless red grapes'],
#  ['chocolate peanut butter ice cream',
#   'baby moisture wash',
#   'herbal body envy',
#   'signature recipes vodka sauce pasta sauce',
#   'jalapeno peppers',
#   'rice sides chicken flavor',
#   'set me up beautiful bold hold hairspray, max',
#   'original breakfast sausage links',
#   'penne pasta',
#   'color treated herbal essences color me happy hair conditioner for color-treated hair 23.7 fl oz female hair care',
#   'extra large grade a eggs',
#   'grands southern homestyle biscuit',
#   'sweet onions',
#   'rice sides chicken flavor broccoli',
#   'green bell pepper',
#   'pasta sides chicken flavor',
#   'honey mustard and onion pretzels pieces',
#   'macaroni & cheese dinner original flavor',
#   'sesame topped hamburger buns',
#   'whole milk',
#   'red peppers',
#   'charcoal briquets easy light bag',
#   'chocolate chip cookie dough',
#   'organic seasoned yukon select potatoes hashed browns',
#   'original slices pepperoni'],
#  ['whole wheat bunnies baked snack crackers',
#   '1 apple + 1 pear fruit bar',
#   'organic cucumber',
#   'creamy peanut butter'],
#  ['watermelon chunks',
#   'all natural powder cleanser',
#   'lemongrass citrus scent disinfecting wipes',
#   'tomato ketchup',
#   'liquid hand soap, refill, lavender scent'],
#  ['kitchen cleaner + bleach, fresh scent',
#   'paper towels',
#   'frappuccino vanilla chilled coffee drink coffee substitutes',
#   'maxi pads overnight with flexi-wings',
#   'original orange juice',
#   'fresh donuts',
#   'organic unsalted butter',
#   'traditional hearty chicken and rotini soup',
#   'organic light in sodium lentil vegetable soup',
#   'electrolyte enhanced water',
#   'mexican blend cheese',
#   'rich & hearty chicken & homestyle noodles soup'],
#  ['organic red radish, bunch',
#   'b 12 liquid b complex',
#   'organic lemon',
#   'beef top round steak',
#   'banana',
#   'organic iceberg lettuce',
#   'cotija',
#   'jalapeno peppers'],
#  ['strawberries',
#   'air chilled organic boneless skinless chicken breasts',
#   'organic chai tea latte concentrate',
#   'roasted turkey'],
#  ['organic nectarine',
#   'bread crumbs',
#   'organic baby spinach',
#   'russet potato'],
#  ['chicken parmesan',
#   'american cheese slices 12 count',
#   'grade a large white eggs',
#   'total 0% with honey nonfat greek strained yogurt',
#   'italian sausage pizza',
#   'original flavor crispy corn snacks',
#   'french vanilla sugar free liquid coffee creamer',
#   'sea salted reduced fat potato chips',
#   'cheese pizza snacks'],
#  ['marinara sauce',
#   'roasted & salted shelled pistachios',
#   'vanilla soy milk',
#   'original new orleans style dirty rice mix'],
#  ['fresh cauliflower'],
#  ['pure sparkling water',
#   'unsalted pure irish butter',
#   'otria spinach artichoke greek yogurt veggie dip',
#   'classico traditional pizza sauce',
#   'sparkling water berry',
#   'pure & natural sour cream',
#   'organic promise berry fruitful cereal',
#   'colombian peaks whole bean coffee'],
#  ['baby cucumbers',
#   'fresh asparagus',
#   'rainbow bell peppers',
#   'red seedless grapes'],
#  ['6 oz la panzanella crostini original crackers',
#   'tomato sauce',
#   'pitted castelvetrano green olives',
#   'pizza dough',
#   'extra virgin olive oil',
#   'organic tomato sauce no salt added',
#   'organic premium tomato paste',
#   'shredded mozzarella'],
#  ['mini peppers',
#   'organic blackberries',
#   'asparagus tips',
#   'organic fuji apple',
#   'cauliflower florets',
#   'lime diet coke',
#   'low fat cottage cheese',
#   'total 0% nonfat plain greek yogurt',
#   'light wisconsin string cheese'],
#  ['original baked snack crackers',
#   'high-traffic foam large area carpet cleaner'],
#  ['carrots', 'organic sliced bella mushrooms'],
#  ['blackberry yogurt',
#   'organic butternut squash',
#   'organic blackberries',
#   "lightly seasoned chick'n scallopini",
#   'organic cut green beans',
#   'vegan smooth chocolate nutritional shake',
#   'organic broccoli',
#   'natural spring water',
#   'organic whole string cheese'],
#  ['sourdough hard pretzels fat free',
#   'white horseradish',
#   'organic red radish, bunch',
#   'gluten free quiche & pie crusts',
#   '1 apple + 1 pear fruit bar',
#   'curly parsley bunch',
#   'broccoli rabe'],
#  ['organic whole wheat pie 9\\ shells 2 ct""',
#   'original hummus',
#   'organic whole string cheese',
#   'medium cheddar cheese block',
#   'frozen organic wild blueberries',
#   'maple quinoa cluster with chia seeds',
#   'organic snack mix bunnies snack mix, organic',
#   'the \\world\'s best\\"" veggie burger""',
#   'organic orzo',
#   'organic milk',
#   'shredded mozzarella',
#   'bag of organic bananas',
#   'organic california style sprouted bread',
#   'gluten free blueberry waffles',
#   'thin & light tortilla chips',
#   'organic roasted turkey breast'],
#  ['whole milk plain yogurt',
#   'apple blueberry granola',
#   'vanilla whey protein powder',
#   'low fat plain yogurt',
#   'boneless skinless chicken breasts'],
#  ['strawberries',
#   'scoops! tortilla chips',
#   'chili with beans',
#   '100 calorie  per bag popcorn',
#   'star wars italian sweet creme creamer',
#   'blueberries',
#   'natural classic pork breakfast sausage',
#   'iced oatmeal cookie kid z bar'],
#  ['organic beef uncured hot dogs',
#   'uncured italian dry salami',
#   'bag of organic bananas',
#   'organic penne rigate',
#   'organic white basmati rice',
#   'lacinato kale og',
#   'red peppers'],
#  ['baby seedless cucumbers',
#   'tilapia filet',
#   'organic bunch arugula',
#   'juice, watermelon + peach, comfort',
#   'organic whole milk',
#   '85% lean ground beef',
#   'coconut water',
#   'cookies, chocolate chip walnut',
#   'small dog biscuits',
#   'bag of organic bananas',
#   'organic bunny fruit snacks berry patch',
#   'organic super fruit punch juice drink'],
#  ['three cheese pizza shell',
#   'sea salt lentil chips',
#   'radish',
#   'organic large extra fancy fuji apple',
#   'nonfat icelandic style strawberry yogurt',
#   'unsweetened coconut milk beverage',
#   'banana',
#   'organic vidalia onion',
#   'wild skipjack light tuna'],
#  ['organic red radish, bunch',
#   'parchment baking paper',
#   'organic garlic',
#   'i heart baby kale',
#   'organic yellow onion',
#   'organic cilantro',
#   'organic lemon',
#   'organic kale',
#   'pita bread',
#   'yellow potato',
#   'organic saffron',
#   'high heat canola spray oil'],
#  ['premium organic strawberry spread',
#   'vegan chao creamy original cheese slices',
#   'chorizo seitan',
#   'peanut butter creamy with salt',
#   'ezekiel 4:9 sprouted whole grain cereal almond',
#   'original pure creamy almond milk'],
#  ['original enriched rice drink'],
#  ['extra sharp cheddar cheese',
#   'original potato chips',
#   'total 2% all natural plain greek yogurt',
#   'roasted sesame seaweed snacks',
#   'all natural virgin lemonade',
#   'vitamin d organic whole milk',
#   'vanilla milk chocolate almond ice cream bars',
#   'total 0% nonfat plain greek yogurt',
#   'eggo homestyle waffles',
#   'all natural marinara sauce',
#   'fruit roll-ups strawberry sensation fruit flavored snacks'],
#  ['lightly salted baked snap pea crisps',
#   'oven baked cheddar & sour cream potato crisps',
#   'organic baby spinach',
#   'original whole grain chips',
#   'boomchickapop sea salt popcorn'],
#  ['organic cream cheese bar',
#   'organic grade a free range large brown eggs',
#   'roasted & salted almonds'],
#  ['organic yellow onion',
#   'organic cinnamon apple sauce',
#   'baby back pork ribs',
#   'bright beet juice smoothie',
#   'lemon cayenne agave cold pressed juice beverage'],
#  ['passion orange guava juice',
#   'organic frozen peas',
#   'organic yellow onion',
#   'organic russet potato',
#   'organic baby spinach'],
#  ['tamari brown rice crackers',
#   'vegetable classics minestrone soup',
#   'ginger beer',
#   'baked rice and corn puffs, aged white cheddar',
#   'organic large grade aa brown eggs',
#   'frozen organic peach slices'],
#  ['organic green tea',
#   'chunky chocolate chip cookies',
#   'lemon-lime fridge pack soda',
#   'earl grey  black tea blend',
#   "crunchy oats 'n honey granola",
#   'english breakfast tea bags',
#   'white giant paper towel rolls',
#   'coke classic',
#   'fridge pack cola',
#   '2% reduced fat milk'],
#  ['extra sharp cheddar cheese block',
#   'slim can pink grapefruit natural mineral water',
#   "chocolate peanut butter builder's bar",
#   'fat free milk',
#   'red hot original cayenne pepper sauce'],
#  ['banana',
#   'sharp cheddar cheese shredded',
#   '100 calorie  per bag popcorn',
#   'whole grain white corn salted tortilla chips',
#   'salted sweet cream butter',
#   'lemon-lime soda',
#   'classic macaroni & beef in tomato sauce. classic macaroni & beef',
#   'broccoli florets steamers',
#   'yellow onions',
#   'organic red onion',
#   'deli fresh honey ham, 97% fat free, gluten free',
#   'unsweetened almondmilk',
#   'diet root beer',
#   'ready wipe flushable wipes',
#   'classic wheat bread'],
#  ['broccoli crown',
#   'tuna salad',
#   'carrots',
#   'cheddar bunnies snack crackers',
#   'organic lactose free 1% lowfat milk',
#   'organic unsalted butter',
#   'organic gluten free & wheat free pumpkin spice waffles',
#   'low fat cottage cheese',
#   'vanilla skyr nonfat yogurt'],
#  ['mixed fruit fruit snacks', 'extra fancy unsalted mixed nuts'],
#  ['cheez-it baked snack crackers',
#   'blackberries',
#   'cinnamon brown sugar breakfast biscuits',
#   'spring water',
#   'strawberries',
#   'oranges',
#   'shredded mexican blend cheese',
#   'apples',
#   'mixed fruit fruit snacks',
#   'red seedless grapes'],
#  ['sesame seed',
#   'organic cinnamon crunch cereal',
#   'organic skim milk',
#   'crunchy peanut butter',
#   'light brown sugar',
#   'green bell pepper',
#   'vanilla almond breeze almond milk',
#   'yellow onions',
#   'fresh ginger root',
#   'red peppers',
#   'carrots',
#   'sweet red chili dipping & all-purpose sauce'],
#  ['organic yukon select fries',
#   'crackers harvest whole wheat',
#   'simply white natural clean mint fluoride toothpaste',
#   'organic large green asparagus',
#   'cage free large white eggs',
#   'organic baby spinach',
#   'organic coconut milk',
#   'mango chunks'],
#  ['garlic alfredo sauce', 'pita crisps simply naked'],
#  ['organic raisin bran cereal', 'tesora medium roast'],
#  ['organic sweet cherries', 'granulated sugar'],
#  ['clementines', 'dried mango', 'mango peach salsa', 'bag of organic bananas'],
#  ['organic smoked turkey breast',
#   'kiwi sandia sparkling water',
#   'peach pear flavored sparkling water',
#   'organic gluten free & wheat free pumpkin spice waffles'],
#  ['white cheddar macaroni & cheese cups',
#   'paleo blueberry muffin',
#   'original hummus'],
#  ['organic butternut squash',
#   'organic hazelnut spread',
#   'organic heavy whipping cream',
#   'premium fish sauce',
#   'premium pure cane granulated sugar',
#   'organic red bell pepper'],
#  ['mild salsa', 'chocolate chip cookie dough ice cream'],
#  ['matcha powder',
#   'parsley, italian (flat), new england grown',
#   'organic mint'],
#  ['cold-pressed organic grapefruit',
#   'plain greek yogurt',
#   'banana',
#   'organic raspberries',
#   'organic traditional plain kefir'],
#  ['italian sparkling mineral water',
#   'mild cheddar cheese sticks',
#   'organic baby arugula',
#   'organic cucumber'],
#  ['chocolate malt',
#   'organic strawberries',
#   'pomegranate',
#   'yogurt, nonfat, organic, plain',
#   'organic red delicious apple'],
#  ['vanilla ice cream',
#   'diet coke soda',
#   'chocolate chip cookie dough ice cream',
#   'dulce de leche caramel ice cream',
#   'coffee ice cream'],
#  ['dairy free cultured plain coconut milk',
#   'fresh cauliflower',
#   'whole almonds',
#   'basil',
#   'jumbo veggie protein smart dogs links',
#   'dairy free mozarella style shreds'],
#  ['organic baby arugula',
#   'organic cucumber',
#   'fresh whole milk ricotta',
#   'large alfresco eggs',
#   'limes',
#   'organic milk chocolate peanut butter cups',
#   'original hummus',
#   'bag of organic bananas',
#   'sharp cheddar cheese',
#   'organic raspberries',
#   'original puffins cereal',
#   'organic fuji red apple chips',
#   'organic soft wheat bread',
#   'seedless red grapes',
#   'baby food stage 2 pumpkin banana'],
#  ['romaine hearts',
#   'traditional favorites italian sausage with peppers & onions pasta sauce',
#   'michigan organic kale'],
#  ['triple blade cartridges',
#   'free & clear ultra powdered laundry detergent',
#   'tilapia filet',
#   'natural free & clear dish liquid',
#   'organic lacinato (dinosaur) kale',
#   'organic quinoa dark chocolate bar'],
#  ['gourmet cut caesar croutons',
#   'baked scalloped potatoes with real cheddar cheese & whole milk',
#   'mashed potatoes garlic id 525 refrigerated sides',
#   'creamy caesar dressing',
#   'condensed golden mushroom soup',
#   'assorted bites',
#   'salad hearts of romaine',
#   'shredded parmesan cheese'],
#  ['lunchables uploaded deep dish pizza with pepperoni',
#   'red seedless grapes',
#   'uncured slow cooked ham',
#   'fridge pack cola'],
#  ['garlic herb goat cheese log',
#   'rosemary crackers',
#   'uncured genoa salami',
#   'original real vegetable chips'],
#  ['organic gluten free pancake & baking mix',
#   'organic banana chips',
#   'organic baby spinach',
#   'non-dairy organic chocolate hazelnut fudge frozen dessert',
#   '100% recycled paper towels',
#   '100% recycled bathroom tissue',
#   'brown eggs'],
#  ['de mexico'],
#  ['organic salted butter', 'organic ketchup', 'premium grapefruit large'],
#  ['pico de gallo beans & rice chips',
#   'total 2% all natural plain greek yogurt',
#   'sprouted whole wheat bread',
#   'sweet rejuvenation cashew butter macrobar'],
#  ['apples & mangoes fruit bars',
#   'organic yellow mustard',
#   'laundry detergent free & clear',
#   'organic garlic',
#   'organic fuji apple',
#   'banana',
#   'fresh cauliflower',
#   'whole almonds',
#   'fresh fussilli',
#   'organic milk',
#   'island vanilla cereal'],
#  ['no salt added black beans',
#   'banana',
#   'frozen broccoli florets',
#   'asparagus spears',
#   'green peas',
#   'organic acai berry smoothie packs',
#   'red raspberries',
#   'cacao sweet raw chocolate nibs',
#   'organic raspberries',
#   'italian sparkling mineral water'],
#  ["organic d'anjou pears",
#   'total 2% lowfat plain greek yogurt',
#   'bok choy',
#   'sourdough bread',
#   'romaine lettuce',
#   'organic yellow onion',
#   'boniato sweet potato',
#   'organic lemon',
#   'organic red onion'],
#  ['mango chunks',
#   'banana',
#   'organic baby spinach',
#   'dairy free unsweetened vanilla coconut milk',
#   'shredded mozzarella',
#   'blueberries',
#   'fresh whole white mushrooms',
#   'apricot'],
#  ['chunky peanut butter'],
#  ['shredded mild cheddar cheese',
#   'pico de gallo chunky salsa',
#   'organic flour tortillas',
#   'sea salt pita chips',
#   'organic baby arugula'],
#  ['organic lacinato (dinosaur) kale',
#   'bag of organic bananas',
#   'organic spinach bunch',
#   "organic d'anjou pears",
#   'organic alfalfa sprouts',
#   'turmeric root',
#   'organic lemon',
#   'frozen organic wild blueberries',
#   'green bell pepper',
#   'organic cilantro',
#   'organic blackberries',
#   'walnut halves & pieces',
#   'organic celery'],
#  ['organic broccoli florets',
#   'semi-sweet mini chocolate chips',
#   'organic unsweetened vanilla almond milk',
#   'banana',
#   'pinto beans no salt added'],
#  ['honey yoghurt',
#   'assorted herbal tea',
#   'black tea variety pack',
#   'white tea peach mango tea bags',
#   'lemon yogurt'],
#  ['pure baking soda',
#   'pineapple orange banana 100% juice',
#   'peppermint mocha liquid coffee creamer',
#   'salad, cobb',
#   'angel food white cake mix',
#   'strawberries',
#   'banana'],
#  ['goo berry pie probugs kefir',
#   'large alfresco eggs',
#   'organic thompson seedless raisins',
#   'organic leek',
#   'strawberry organic kefir',
#   'organic garlic'],
#  ['organic sticks low moisture part skim mozzarella string cheese',
#   'eggo blueberry waffles',
#   'pure sparkling water',
#   'organic whole milk with dha omega-3',
#   'muscat grape jelly',
#   'crunch time'],
#  ['multi grain sandwich thins',
#   'quaker life cinnamon cereal',
#   'original fresh stack crackers',
#   'italian dry salame',
#   'banana',
#   'organic edamame',
#   '100% whole wheat bread',
#   'strawberries'],
#  ['romaine lettuce', 'organic fresh basil', 'fancy eggplant'],
#  ['enlightened organic raw kombucha',
#   'spring water',
#   'pure coconut water',
#   'tea tree triple treat shampoo'],
#  ['100% raw coconut water',
#   'organic baby spinach',
#   'reduced fat milk 100% lactose free',
#   'organic coconut milk',
#   'organic extra large brown eggs',
#   'tomato sauce',
#   'organic premium tomato paste',
#   'strawberries'],
#  ['natural deli slices gouda cheese',
#   'spinach souffle',
#   'milano dark chocolate cookies',
#   'noir orange liqueur & cognac'],
#  ['organic gluten free sea salt by the seashore multigrain tortilla chips',
#   'organic fuji red apple chips',
#   'european-style cultured butter',
#   'gogo squeez organic apple strawberry applesauce on the go',
#   "children's silly strawberry fluoride free toothpaste",
#   'cheddar cheese nut thins cracker snacks',
#   'organic low fat plain yogurt',
#   'organic navel orange',
#   'organic lemon',
#   'organic sunday bacon'],
#  ['mountain spring water',
#   'bag of organic bananas',
#   'green moroccan mint tea',
#   'yokids strawberry banana/strawberry yogurt',
#   'organic distilled white vinegar',
#   'sun dried tomato pesto',
#   'organic cheddar crazy bugs macaroni & cheese dinner'],
#  ['clover honey bear',
#   'natural sharp cheddar sliced cheese',
#   'bourbon whiskey',
#   'fresh scent dishwasher detergent',
#   'old fashioned apple cider',
#   'meritage wine',
#   'invisible solid powder fresh antiperspirant/deodorant',
#   'european cucumber'],
#  ['shredded parmesan',
#   'sour cream',
#   'crushed tomatoes',
#   'strawberries',
#   'organic balance milk protein shake dark chocolate',
#   'penne rigate #41 pasta',
#   'cookies, milk chocolate',
#   'bag of organic bananas',
#   'organic homestyle waffles',
#   'shredded mild cheddar cheese',
#   'organic snipped green beans',
#   'heavy cream',
#   'quick-rise yeast for bread machines',
#   'dry rubbed thick sliced pork bacon'],
#  ['unsweetened almondmilk',
#   'organic bunny fruit tropical treat fruit snacks',
#   'organic baby spinach salad',
#   'organic summer strawberry bunny fruit snacks',
#   'english seedless cucumber',
#   'organic strawberries',
#   'organic french roast ground coffee'],
#  ['sushi nori, pacific, organic',
#   'organic short grain brown rice',
#   'unsweetened almond milk',
#   'organic strawberries',
#   'spring water',
#   'creamy almond butter'],
#  ['pumpkin fig ancient grain granola',
#   'sour worms',
#   'organic creamy tomato soup',
#   'banana',
#   'lemon echinacea organic throat coat tea',
#   'total 0% greek yogurt',
#   'organic jelly beans'],
#  ['impressions napkins',
#   '100% whole wheat bread',
#   'diet the original cream soda',
#   'light mayonnaise',
#   'low fat cottage cheese',
#   'bag of organic bananas',
#   'sea salted reduced fat potato chips'],
#  ['bag of large lemons', 'spring water', 'soda'],
#  ['caramels',
#   'hot mexican-style chili powder',
#   'natural medium cheddar cheese',
#   'yellow onions',
#   'organic small curd cottage cheese',
#   'pure & natural sour cream'],
#  ['roasted unsalted almonds'],
#  ['mixed fruit fruit snacks'],
#  ['chocolate peanut butter cup gelato',
#   'shredded mild cheddar cheese',
#   'shredded mozzarella'],
#  ['organic reduced fat 2% milk', 'original orange juice', 'grapefruit juice'],
#  ['super smooth pears pears pears puree 1 (from 4 months)',
#   'whole grains health nut bread',
#   'fresh & fruity arbequina extra virgin olive oil'],
#  ['vegetable oil',
#   'feta crumbled traditional cheese',
#   'jasmine ready rice',
#   'country white bread',
#   'boneless skinless chicken breast fillets'],
#  ['banana',
#   'turkey pepperoni slices',
#   'premium sweet petites carrots',
#   'red mango',
#   'corn maize tortillas'],
#  ['chocolate ice cream',
#   '100% recycled paper towels',
#   'total 0% greek yogurt',
#   'genuine brewed rice vinegar'],
#  ['italian sparkling mineral water',
#   'claw crab meat',
#   'organic unsalted butter',
#   'yukon gold potatoes 5lb bag',
#   'pork chorizo',
#   'fresh cauliflower',
#   'grass fed ground beef',
#   'camilia, single liquid doses',
#   'dried mango'],
#  ['strawberries'],
#  ['organic strawberries', 'key limes', 'honeycrisp apples'],
#  ['cara cara navel orange',
#   'organic baby spinach',
#   'electrolyte enhanced water',
#   'frozen peaches',
#   'organic black beans',
#   'banana',
#   'whole strawberries',
#   'mango chunks',
#   'tortillas, corn, organic',
#   'blueberries'],
#  ['instant oatmeal variety pack',
#   'broccoli crown',
#   'organic hearty split pea & uncured ham soup',
#   'boneless skinless chicken breasts',
#   'organic cream of chicken condensed soup',
#   'colby jack cheese',
#   'banana'],
#  ['organic grass-fed classic mild cheddar macaroni & cheese',
#   'yobaby organic plain yogurt',
#   'organic strawberries',
#   'organic pure 85% dark chocolate bar',
#   'pure sparkling water',
#   'organic pumpkin puree',
#   'organic sprouted english muffin'],
#  ['organic short grain brown rice',
#   'crunchy peanut butter',
#   'extra thick whole grain rolled oats'],
#  ['bag of organic bananas',
#   'hazelnut spread with cocoa',
#   'organic baby spinach'],
#  ['chopped kale',
#   'hearty grains 100% whole wheat english muffins',
#   'green beans'],
#  ['imported mineral water',
#   'gluten free penne',
#   'wheat gluten free waffles',
#   'cranberry juice cocktail',
#   'whole milk'],
#  ['organic fuji apple',
#   'instant oatmeal variety pack',
#   'banana',
#   'organic baby spinach',
#   'shredded mild cheddar cheese',
#   'original orange juice',
#   'organic refried black beans',
#   'broccoli crown'],
#  ['pink grapefruit',
#   '13 gallon tall kitchen bags',
#   'white cheddar popcorn',
#   'green onions',
#   'mini watermelon',
#   'banana',
#   'yellow onions',
#   'white corn',
#   'small hass avocado',
#   'orange mango sparkling water',
#   'bosc pear',
#   'green beans',
#   'cherry limeade',
#   'roma tomato',
#   'white corn tortilla chips',
#   'vanilla and chocolate low fat ice cream sandwiches',
#   'sparkling peach nectarine soda',
#   'light thousand island dressing',
#   'precious mozzarella cheese'],
#  ['bread, double fiber',
#   'peanut butter cereal',
#   'no calorie sweetener packets',
#   'mini classic ice cream',
#   'nectarines',
#   'crunchy corn sticks',
#   'organic 2% reduced fat milk',
#   'chocolate peanut butter ice cream',
#   'spring water',
#   'hannah max crunchy chocolate chip'],
#  ['sparkling lemon water',
#   'organic large grade aa brown eggs',
#   'cookie dough nutrition bar',
#   'cherry pomegranate greek yogurt',
#   'banana',
#   'apple honeycrisp organic',
#   'pure sparkling water'],
#  ['natural shredded mexican style four cheese',
#   'natural chunky peanut butter',
#   'parmesan shredded cheese',
#   'organic soybean spaghetti shape'],
#  ['organic european style lightly salted butter',
#   'el ciprã©s whole bean coffee',
#   'organic cucumber',
#   'organic raspberries',
#   'hakata noodle ramen',
#   'truffle popcorn',
#   'organic garlic',
#   'barista blend pure almond milk',
#   'organic whole strawberries',
#   'i heart baby kale',
#   'bag of organic bananas',
#   'no salt added black beans',
#   'dressing, jersey sweet onion, calorie free',
#   'tuscan kale & quinoa salad',
#   'organic diced tomatoes',
#   'whole wheat sourdough'],
#  ['watermelon lemonade',
#   'cherry vanilla creme soda',
#   'original lemonade',
#   'almond cheddar style shredded cheese alternative',
#   'teriyaki noodle bowl',
#   'almond breeze original almond milk',
#   'bing cherries'],
#  ['ginger twist tea', 'romaine hearts', 'large brown eggs'],
#  ['eggo blueberry waffles',
#   'combination pizza rolls',
#   'migraine pain reliever caplets',
#   'forceflex drawstring tall kitchen bags',
#   'broccoli, carrots, cauliflower, & cheese sauce',
#   'meat lovers breakfast bowl',
#   'vanilla bean ice cream',
#   'organic whole milk',
#   'dulce de leche caramel ice cream',
#   'original nooks & crannies english muffins',
#   'cafã© steamers grilled chicken marinara',
#   'cafã© steamers 100% natural tortellini primavera parmesan',
#   'classic fried chicken frozen dinner',
#   'plates, ultra, 10-1/16 inch',
#   'cafe steamers asian beef teriyaki',
#   'advance white fluoride anticavity tartar control extreme whitening fresh mint flavor toothpaste',
#   'soft & smooth whole grain white bread',
#   'top chef ravioli & chicken marinara'],
#  ['russet potato',
#   'new orleans iced coffee',
#   'thin & light tortilla chips',
#   'natural chicken & apple breakfast sausage patty',
#   'organic american cheese singles',
#   'sriracha arare rice cracker',
#   'panda puffs peanut butter cereal',
#   'organic mountain forest amber honey',
#   'organic yellow onion',
#   'half & half',
#   'carrots',
#   'oven roasted turkey',
#   'organic strawberries',
#   'bag of organic bananas'],
#  ['blackberries', 'blueberries'],
#  ['sustainably soft bath tissue',
#   'broccoli crown',
#   'uncured slow cooked ham',
#   'organic whole strawberries',
#   'pink lemonade vitamin c 1000mg drink mix dietary supplement',
#   'organic garlic'],
#  ['orange bell pepper',
#   'pita chips simply naked',
#   'honey greek yogurt',
#   'organic 1% low fat milk',
#   'organic large brown grade aa cage free eggs',
#   'sonoma traditional flour tortillas 10 count',
#   'milk, organic, vitamin d',
#   'bag of organic bananas',
#   'organic red bell pepper'],
#  ['boneless skinless chicken breasts',
#   'organic baby arugula',
#   'unsweetened almondmilk',
#   'organic avocados',
#   'organic american cheese singles',
#   'crackers, classic saltine'],
#  ['brown rice & vegetables bowl', 'broccoli & cheddar bake meal bowl'],
#  ['lemon verbena hand soap',
#   'crunch granola bar chocolate chip',
#   'organic baby spinach',
#   'organic chicken & apple sausage',
#   'organic summer strawberry bunny fruit snacks',
#   'peanut & gluten free smooth almond butter',
#   'unsweetened almondmilk',
#   'french vanilla soy creamer',
#   'reduced fat milk 100% lactose free',
#   'organic bunny fruit snacks berry patch'],
#  ['flushable moist wipes',
#   'mini peeled carrots',
#   'organic chicken bone broth',
#   'wheat gluten free waffles',
#   'smartwater electrolyte enhanced water',
#   'blueberries',
#   'organic frozen blueberries',
#   'sparkling water',
#   'organic free range low sodium chicken broth',
#   'dairy free unsweetened coconut milk',
#   'organic green onions'],
#  ['g series perform glacier cherry sports drink'],
#  ['strawberries', 'bag of organic bananas', 'green seedless grapes'],
#  ['chicken noodle soup'],
#  ['extra virgin olive oil',
#   'dishwasher gel free & clear',
#   'organic yellow onion',
#   'gluten free multigrain bread',
#   'green peas no salt added'],
#  ['organic animal crackers', 'whole grain cheddar baked snack crackers'],
#  ['organic reduced fat 2% milk'],
#  ['rice express fresh steamed sticky white rice',
#   'gluten free sliced mountain white bread',
#   'everyone aromatherapy essential oil diffuser',
#   'everything bagels',
#   'cantina traditional tortilla chips',
#   'turkey, pepperoni & cheese ready to eat meal kit',
#   'philadelphia garden vegetable light cream cheese',
#   'gluten free plain tortillas',
#   'optic white sparkling mint toothpaste',
#   'beyond beef beefy crumble',
#   'beyond grain free chicken cat food',
#   'singapore sesame ginger street noodles',
#   'cheddar cheese burrito'],
#  ['organic roasted turkey breast',
#   '100% recycled paper towels',
#   'the original caesar dressing',
#   'unsweetened pure & smooth  green tea',
#   'whole hearts of palm',
#   'compostable forks',
#   'organic baby spinach',
#   'gluten free whole grain bread',
#   'organic large extra fancy fuji apple'],
#  ['italian extra virgin olive oil',
#   '100% recycled paper towels',
#   'soft pretzel burger buns',
#   '100% recycled bath tissue rolls',
#   'basil',
#   'organic medium salsa',
#   'pizza dough',
#   'organic baby arugula',
#   'cage free grade a large brown eggs',
#   'seedless watermelon'],
#  ['liquid egg whites'],
#  ['unsweetened almondmilk',
#   'chopped pecans',
#   'tea tree essential oil',
#   'organic cilantro',
#   'organic butterhead (boston, butter, bibb) lettuce',
#   'whole grain pita bread',
#   'organic cucumber',
#   'organic distilled white vinegar',
#   'marinara sauce',
#   'organic red potatoes',
#   'organic lemon',
#   'organic red onion',
#   'mango chunks',
#   'organic baby arugula',
#   'organic baby spinach',
#   'bag of organic bananas',
#   'pure lemon juice',
#   'organic yellow onion',
#   'simply white natural clean mint fluoride toothpaste',
#   'organic roma tomato',
#   'organic garlic hummus'],
#  ['gluteen free center cut applewood smoked uncured bacon',
#   'honey yoghurt',
#   'organic cilantro',
#   'organic red bell pepper'],
#  ['cultured low fat buttermilk'],
#  ['organic fresh squeezed orange juice',
#   'bag of organic bananas',
#   'organic tomato paste',
#   'natural artisan water',
#   '100% whole wheat bread',
#   'total 2% lowfat greek strained yogurt with blueberry',
#   'peanut butter bar',
#   'single serve crispy wheat crackers',
#   'organic strawberries',
#   'organic thompson seedless raisins',
#   'mini cucumbers',
#   'organic appleapple',
#   'mild cheddar cheese sticks',
#   'natural chicken & sage breakfast sausage',
#   'zbar organic chocolate brownie energy snack',
#   'organic whole string cheese',
#   'cinnamon raisin brioche',
#   'spaghetti  no 12',
#   'organic light agave nectar',
#   'organic raspberries'],
#  ['organic banana, cinnamon & granola stage 2 baby food',
#   'organic stage 2 sweet potato garbanzo barley',
#   'baby food stage 2 sweet potato mango & millet',
#   'banana',
#   'cantaloupe grapefruit sparkling water',
#   'stage 3 hearty meals - chick chick organic baby food',
#   'power greens'],
#  ['angel hair pasta',
#   'bunched cilantro',
#   'fat free milk',
#   'supermoist white cake mix',
#   'popcorn party size! white cheddar cheese',
#   'olive oil cooking spray'],
#  ["organic d'anjou pears",
#   'mini original babybel cheese',
#   'total 2% all natural greek strained yogurt with honey',
#   'strawberries',
#   'half & half',
#   'granny smith apples',
#   'banana',
#   'cf hny almnd granola 11'],
#  ['organic & raw strawberry serenity kombucha',
#   'kombucha, organic raw, citrus',
#   'lemon fruit & nut food bar',
#   'passionberry bliss kombucha drink',
#   '100% raw coconut water',
#   'kombucha, organic raw, lavender no. 3',
#   'snacks mango',
#   'coconut cream pie',
# ...
#  ['red peppers',
#   'buttermilk complete pancake mix',
#   'chicken & apple breakfast sausage',
#   'italian ground turkey, lean',
#   'double stuf oreo sandwich cookies',
#   'asian chopped salad with dressing'],
#  ['bag of organic bananas',
#   'organic salted butter',
#   'organic blackberries',
#   'organic whole strawberries',
#   'yobaby peach pear yogurt',
#   'organic raw unfiltered apple cider vinegar'],
#  ['green bell pepper',
#   'broccoli rabe',
#   'shredded mozzarella',
#   'rigatoni pasta',
#   'natural artisan water',
#   'large alfresco eggs',
#   'organic garlic',
#   'traditional scottish style smoked salmon',
#   'organic tomato basil sauce',
#   'organic red onion',
#   'dry pasta lasagne',
#   'shredded parmesan',
#   'english seedless cucumber'],
#  ['banana',
#   'blackberries',
#   'broccoli crown',
#   '85% lean ground beef',
#   'boneless skinless chicken breasts',
#   'russet potato',
#   'strawberries'],
#  ['hot & spicey baked snack crackers',
#   'classic almond butter',
#   'grooves zesty cheddar ranch crackers',
#   'triscuit original baked whole grain wheat crackers'],
#  ['organic baby spinach', 'gluten free chicken dumplings', 'mango chunks'],
#  ['strawberry rhubarb yoghurt',
#   'boneless skinless chicken breasts',
#   'organic zucchini spirals',
#   'bag of organic bananas',
#   'garnet sweet potato (yam)',
#   'bone organic chicken with ginger broth'],
#  ['protein zone protein juice smoothie', '15 calories light lemonade'],
#  ['cacao sweet raw chocolate nibs',
#   'organic baby kale mix',
#   'jazz apple',
#   'no. 01 organic vegan cold pressed juice kale spinach romaine celery cucumber apple lemon'],
#  ['organic broccoli',
#   'organic lemon',
#   'organic large extra fancy fuji apple',
#   'organic lacinato (dinosaur) kale',
#   'organic cucumber',
#   'gluten free brown rice bread',
#   'organic yellow onion',
#   'organic grade a free range large brown eggs',
#   'organic carrot bunch',
#   'rocky mountain sourdough bread',
#   'premium organic strawberry spread',
#   'bag of organic bananas',
#   'peanut & gluten free smooth almond butter',
#   'taco seasoning',
#   'organic garlic',
#   'organic butternut squash',
#   'organic iceberg lettuce',
#   'dark chocolate frozen dessert bars',
#   'almond milk blueberry yogurt',
#   'unsweetened almondmilk',
#   'michigan organic kale'],
#  ['mixed berries whole milk icelandic style skyr yogurt',
#   'strawberry rhubarb yogurt',
#   'organic black beans',
#   'ancient grain blueberry hemp granola',
#   'organic raspberries',
#   'organic sea salt dark chocolate',
#   'ancient grain granola cranberry pecan',
#   'lemon hummus',
#   'pumpkin fig ancient grain granola'],
#  ['organic red radish, bunch',
#   'organic cucumber',
#   'organic baby spinach',
#   'frozen organic wild blueberries',
#   'organic whole grassmilk milk'],
#  ['organic celery',
#   'walnut halves & pieces',
#   'lowfat small curd cottage cheese',
#   'organic whole strawberries',
#   'organic whole milk',
#   'ravioli, spinach & cheese',
#   'organic chopped garlic'],
#  ['select-a-size white paper towels',
#   'zero rise orange',
#   'roma tomato',
#   'yellow onions',
#   'chicken broccoli supreme',
#   'protein plus farfalle multigrain pasta',
#   'cinnamon raisin swirl pre-sliced bagels',
#   'tomato and basil pasta sauce',
#   'philadelphia cream cheese'],
#  ['sour cream',
#   'carrots',
#   'mild sliced cheddar cheese',
#   'organic garlic',
#   'organic leek',
#   'boneless skinless chicken breast',
#   'organic baby arugula',
#   'cream top smooth & creamy vanilla yogurt',
#   'organic no salt added diced tomatoes',
#   'organic vegetable broth',
#   'original hummus',
#   'half & half',
#   'organic reduced fat 2% milk',
#   'low fat 1% milk',
#   'bag of organic bananas'],
#  ['smoked wild sockeye salmon', 'homemade hot arrabbiata fra diavolo sauce'],
#  ['organic mushroom chef s sampler',
#   'tomato basil bisque rts organic soup',
#   'light & lean roasted polenta with swiss chard',
#   'organic all stars pasta in tomato & cheese sauce',
#   'light & lean spaghetti italiano with meatless meatballs',
#   '2% reduced fat milk',
#   'organic baby spinach',
#   'sensitive facial cleansing towelettes',
#   'oh my yog! pacific coast strawberry trilayer yogurt',
#   "organic bernie o's",
#   'tommy/kent/keitt/haden mango',
#   'spaghetti',
#   'egg & smoked gouda multi-grain flatbread breakfast sandwich',
#   'pizza roasted vegetable no cheese',
#   'watermelon chunks',
#   'stuffed grape leaves'],
#  ['organic whole string cheese',
#   'banana',
#   'whole milk plain yogurt',
#   'organic whole milk'],
#  ['romaine hearts',
#   'organic large extra fancy fuji apple',
#   'green beans',
#   'organic strawberries'],
#  ['organic lemon',
#   'garlic & fine herbs gournay cheese',
#   'jamon serrano dry cured ham',
#   'tahitian vanilla gelato'],
#  ['smartwater',
#   'organic strawberries',
#   'basil dish soap',
#   'banana',
#   'white cheddar jalapeno gourmet popcorn',
#   'gluten free mini pretzels',
#   'organic chives',
#   'shredded 3 cheese blend',
#   'jalapeno hummus',
#   'organic whole string cheese',
#   'mild cheddar cheese sticks',
#   'russet potato',
#   'tuscan vodka fresh pasta sauce',
#   'organic fuji apple',
#   'shredded parmesan'],
#  ['mini babybel mozzarella cheese',
#   'coffee blended low-fat greek yogurt',
#   'plain greek yogurt',
#   '0% milkfat greek yogurt honey',
#   'white cheddar semisoft cheese',
#   'blueberry on the bottom nonfat greek yogurt',
#   'pomegranate on the bottom non-fat greek yogurt',
#   'organic 2% reduced fat milk'],
#  ['extra virgin olive oil',
#   'organic pizza snack mix crackers',
#   'diced tomatoes',
#   'organic macaroni & cheese',
#   'dressing, jersey sweet onion, calorie free',
#   'chopped spinach'],
#  ['root beer soda', 'ginger ale'],
#  ['baby seedless cucumbers',
#   "sheep's milk halloumi cheese",
#   'aged white cheddar baked rice & corn puffs gluten free lunch packs',
#   'organic shredded mild cheddar',
#   'organic freeze dried bananas',
#   'tomatoes, whole peeled',
#   'kitchen scrubber sponge',
#   'organic whole grain wheat english muffins',
#   'banana',
#   'tommy/kent/keitt/haden mango',
#   'organic unsalted butter',
#   'organic yellow onion',
#   'organic fancy shredded mozzarella cheese',
#   'organic whole string cheese',
#   'frozen organic mango chunks',
#   'crispy wheat, crackers',
#   'premium mango fruit snack pack',
#   'organic freeze dried strawberries',
#   'american cheese slices'],
#  ['watermelon chunks',
#   'organic whole milk french vanilla yogurt',
#   'whole milk plain yogurt',
#   '100% whole wheat bread',
#   'organic baby spinach',
#   'no pulp orange juice'],
#  ['pro-health for me cross action toothbrush',
#   'banana',
#   'cheerios cereal',
#   'santa cruz og apricot fruit spread',
#   'santa cruz og blackberry pom fruit spread',
#   'unsweetened almondmilk',
#   'thick medium cheddar slices',
#   'eggo homestyle waffles',
#   'soft & chewy strawberry newtons',
#   'canned diet',
#   'bathroom tissue double rolls',
#   'berry bunnies cereal organic',
#   'max force laundry stain remover',
#   'wholesome breakfast apple raisin baby food',
#   'natural lemon flavored sparkling water',
#   'dha omega 3 vitamin d milk',
#   'passionfruit sparkling water',
#   'mexican finely shredded cheese'],
#  ['fruit flavored snacks assorted flavors',
#   'mandarin orange segments in light syrup',
#   'fettuccini with chicken broccoli',
#   'sour cream & onion flavored potato chips',
#   'aluminum foil',
#   'berry punch flavored fruit drink'],
#  ['corn tortillas', 'organic guacamole'],
#  ['organic white english muffins',
#   'organic romaine',
#   'green beans',
#   'organic yokids lemonade/blueberry variety pack yogurt squeezers tubes',
#   'organic baby spinach',
#   'extra wide egg noodles',
#   'tilapia filet',
#   'breaded fish sticks',
#   'organic cucumber',
#   'original enriched rice drink',
#   'organic mini homestyle waffles'],
#  ['banana', 'organic sweet potato puree', 'go lean cereal'],
#  ['dairy free coconut milk raspberry yogurt alternative',
#   'mixed berries whole milk icelandic style skyr yogurt',
#   'milk, reduced fat, 2% milkfat',
#   'unsweetened almondmilk',
#   'strained whole-milk yogurt blueberry',
#   'original puffins cereal',
#   'unsweetened green tea',
#   'sparkling water berry',
#   'pure sparkling water',
#   'bag of organic bananas',
#   'pretzel sticks, thin',
#   'small hass avocado',
#   'vitaminwaterâ® xxx acai blueberry pomegranate',
#   'sparkling lemon water',
#   'peach pear flavored sparkling water',
#   'strawberry rhubarb yogurt'],
#  ['sliced peaches',
#   'banana',
#   'michigan organic kale',
#   'bunched carrots',
#   'strawberries',
#   'chicken broth'],
#  ['granny smith apples',
#   'whole milk',
#   'mountain chai black & spices concentrate',
#   'seedless red grapes',
#   'original pure creamy almond milk'],
#  ['diet mountain zevia soda',
#   'tomato ketchup',
#   'organic restaurant style  sea salt & lime tortilla chips',
#   'glutenfree brownie mix'],
#  ['vanilla soy milk',
#   'pure peppermint herbal tea',
#   'organic green tea lemongrass',
#   'vanilla almond breeze',
#   'banana',
#   'clementines'],
#  ['original hummus',
#   'organic baby spinach salad',
#   'mixed berries whole milk icelandic style skyr yogurt',
#   'icelandic style skyr blueberry non-fat yogurt',
#   'white peach',
#   'house napa cabbage',
#   'peanut butter creamy with salt',
#   'blueberries',
#   'whole strawberries'],
#  ['no beans chili',
#   'chunky salsa medium',
#   'mini & meatballs in tomato sauce beef ravioli',
#   'scoops! tortilla chips',
#   'soda',
#   'diet caffeine free soda',
#   'flour corn tortillas filled with chicken and vegetables over a bed of rice topped with a real cheese sauce chicken enchiladas',
#   'rigatoni with chicken & pesto',
#   'extra fresh body wash with pump',
#   'blueberry lemonade',
#   'sausage, egg, & cheese croissant',
#   'ranch dressing'],
#  ['organic baby spinach',
#   'organic soba',
#   'oats & honey gluten free granola',
#   'milk, organic, vitamin d'],
#  ['organic raspberries',
#   'bag of organic bananas',
#   'kefir cultured milk smoothie, whole milk, sublime slime lime',
#   'organic cucumber',
#   'organic roma tomato',
#   'organic baby spinach'],
#  ['organic roma tomato',
#   'barista blend pure almond milk',
#   'organic black lentils',
#   'banana',
#   'italian sparkling mineral water',
#   'lavender dish soap',
#   'tilapia filet',
#   'organic lemon'],
#  ['classic french demi-glace',
#   'red raspberries',
#   'non fat acai & mixed berries yogurt'],
#  ['apricots',
#   'organic strawberries',
#   'seedless cucumbers',
#   'granny smith apples',
#   'clementines',
#   'premium grapefruit large',
#   'hass avocado variety'],
#  ['limes',
#   'thick & chunky salsa',
#   'boneless skinless chicken breasts',
#   'sliced black olives',
#   'bunched cilantro',
#   'colby jack cheese'],
#  ['baby arugula',
#   'apple honeycrisp organic',
#   'tart cherry yoghurt',
#   'cold brew coffee double espresso with almond milk',
#   'organic raw kombucha gingerade',
#   'banana',
#   'hearty nine grain bread',
#   'vanilla yogurt',
#   'seedless red grapes',
#   'seedless small watermelon',
#   "organic cookies 'n cream ice cream",
#   'half & half',
#   'marinara sauce'],
#  ['organic bread with 21 whole grains',
#   'coconut milk yogurt alternative natural flavor',
#   'frozen organic wild blueberries',
#   'organic large extra fancy fuji apple',
#   'organic coconut milk',
#   'organic lemon'],
#  ['sourdough bread',
#   'organic infant formula with iron',
#   'organic strawberries',
#   'sprouted whole wheat bread',
#   'banana',
#   'organic whipped naturally buttery spread',
#   'organic low sodium vegetable broth'],
#  ['organic large extra fancy fuji apple',
#   'apple honeycrisp organic',
#   'persimmon sharon fruit cv',
#   'banana',
#   "organic d'anjou pears"],
#  ['lavender floral & mint natural dish liquid',
#   '3d white mint toothpaste',
#   'organic lemon',
#   'red peppers',
#   'thirsty ultra big roll towel white vsa',
#   'limes',
#   'medium cheddar cheese',
#   'bunched cilantro',
#   'uncured genoa salami',
#   'white whole mushrooms',
#   'jalapeno peppers',
#   'rosemary crackers',
#   'pro-v daily moisture renewal conditioner'],
#  ['michigan organic kale',
#   'steel cut oats with currants, flax and chia',
#   'gluten free brown rice bread',
#   'sunflower seed butter',
#   'tortillas, brown rice'],
#  ['organic strawberries',
#   'talenti double dark chocolate gelato',
#   'original whole fat lactose free milk',
#   'black cherry gelato',
#   'fresh ginger root',
#   'seedless small watermelon'],
#  ['coconut water', 'semi-sweet chocolate morsels'],
#  ['blueberry pint',
#   'cheese enchilada meal',
#   'indian samosa wrap',
#   'black bean tamale verde',
#   'cheese tamale verde',
#   'indian paneer tikka',
#   'icelandic style fat free plain yogurt'],
#  ['the original worcestershire sauce',
#   'limes',
#   'original no pulp 100% florida orange juice',
#   'red hot original cayenne pepper sauce'],
#  ['uncured slow cooked ham',
#   'mandarins',
#   'organic baby spinach salad',
#   'banana'],
#  ['european cucumber',
#   'organic short grain brown rice',
#   'iceberg lettuce',
#   'organic 2% reduced fat milk',
#   'baguette sourdough'],
#  ['millet & brown rice ramen', 'carrots', 'organic udon', 'russet potato'],
#  ['seedless red grapes',
#   'original semisoft cheese',
#   'organic lactose free 1% lowfat milk',
#   'organic mountain forest amber honey',
#   'sweet potato littles',
#   '100% goats milk'],
#  ['organic cucumber',
#   'orignial recipe chocolate pudding',
#   'seedless red grapes',
#   'organic penne rigate',
#   'bag of organic bananas',
#   '100% whole wheat bread'],
#  ['sweet corn on the cob',
#   'smoked gouda',
#   'thin sliced mozzarella cheese',
#   'multi-seed original crackers',
#   'carrots',
#   'whole kernel corn',
#   'celery bunch',
#   'orecchiette dry pasta',
#   'mediterranee strawberry yogurt',
#   'coconut yogurt',
#   'english peas',
#   'pain reliever and fever reducer tablets',
#   'cannellini white kidney beans no salt added',
#   'artisan sesame seeds nut & rice cracker snacks'],
#  ['baby spinach'],
#  ['orange with mango juice'],
#  ['pomegranate and currant soy wax candle',
#   'brightening hydro serum facial mask'],
#  ["lightly seasoned chick'n scallopini",
#   "jack's special mild salsa",
#   'caffeine free coke zero'],
#  ['mediterranean fine sea salt',
#   'pure ground black pepper',
#   'cola soda',
#   'thin spaghetti',
#   'fresh whole garlic',
#   'white italian bread'],
#  ['red peppers',
#   'limes',
#   'jalapeno peppers',
#   'organic yellow onion',
#   'thin rice noodles',
#   'organic extra large brown eggs',
#   'organic large extra fancy fuji apple',
#   'organic cilantro',
#   'cultured buttermilk',
#   'organic carrot bunch',
#   'toasted coconut almondmilk blend',
#   'napa cabbage',
#   'lightly sweet popcorn',
#   'organic garlic'],
#  ['organic whipping cream',
#   'santa maria seasoning',
#   'organic sprinkle 24 herbs & spices seasoning'],
#  ['light semisoft cheese'],
#  ['total 2% lowfat plain greek yogurt', 'total 0% nonfat plain greek yogurt'],
#  ['large grade aa cage free eggs',
#   'cola soft drink',
#   'pure protein chocolate peanut butter bars',
#   'chocolate favorites fun size variety pack',
#   'half & half',
#   'small hass avocado',
#   'original nooks & crannies english muffins',
#   'crunchy peanut butter granola',
#   'french vanilla creme protein energy bars',
#   'pure water',
#   'original fruit chews',
#   'wheaties'],
#  ['vegetarian organic golden corn',
#   'jalapeno peppers',
#   'banana',
#   'organic fuji apple',
#   'yellow bell pepper',
#   'taco seasoning'],
#  ['banana',
#   'organic chopped spinach',
#   'ruby red grapefruit',
#   'drinkable blueberry non-fat yogurt',
#   'non-fat vanilla yogurt'],
#  ['cold brew coffee double espresso with almond milk',
#   'organic baby arugula',
#   'organic fuji apple',
#   'organic hazelnut spread'],
#  ['organic mint confetti ice cream',
#   'organic mountain forest amber honey',
#   'madagascar vanilla ice cream',
#   'backyard barbeque potato chips'],
#  ['merlot'],
#  ['carrot juice organic pure originals', 'original hummus'],
#  ['organic medjool dates',
#   'organic mint bunch',
#   'coconut milk yogurt alternative natural flavor',
#   'italian extra virgin olive oil',
#   'organic orzo',
#   'organic cilantro bunch'],
#  ['tilapia filet',
#   'enlightened organic raw kombucha',
#   'banana',
#   'wild chanterelle mushroom ravioli',
#   'shredded parmesan',
#   'strawberry rhubarb yoghurt',
#   'organic white chocolate peanut butter cups',
#   'organic flour tortillas',
#   'shredded mild cheddar cheese',
#   'demerara cane sugar cubes'],
#  ...]

# %% [markdown]
# #### Testing APRIORI algorithm
#
# 1) Encode data.

# %%
te = TransactionEncoder()
te_ary = te.fit(selection).transform(selection)
te_ary
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
encoded_df = pd.DataFrame(te_ary, columns = te.columns_)
encoded_df.head()
# Out:
#    #2 coffee filters  #2 cone white coffee filters  \
# 0              False                         False
# 1              False                         False
# 2              False                         False
# 3              False                         False
# 4              False                         False
#
#    #4 natural brown coffee filters  & go! hazelnut spread + pretzel sticks  \
# 0                            False                                   False
# 1                            False                                   False
# 2                            False                                   False
# 3                            False                                   False
# 4                            False                                   False
#
#    +energy black cherry vegetable & fruit juice  .5\ waterproof tape""  \
# 0                                         False                  False
# 1                                         False                  False
# 2                                         False                  False
# 3                                         False                  False
# 4                                         False                  False
#
#    0 calorie acai raspberry water beverage  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    0 calorie fuji apple pear water beverage  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    0 calorie strawberry dragonfruit water beverage  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    0% fat black cherry greek yogurt y  ...  zoe organic evoo  \
# 0                               False  ...             False
# 1                               False  ...             False
# 2                               False  ...             False
# 3                               False  ...             False
# 4                               False  ...             False
#
#    zucchini noodles  zucchini pancakes  zucchini soufflã©  \
# 0             False              False              False
# 1             False              False              False
# 2             False              False              False
# 3             False              False              False
# 4             False              False              False
#
#    zucchini squash, baby courgette  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    zucchini, spinach & banana blend veggies on-the-go stage 2 (6 months and up)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    zyflamend whole body liquid vcaps  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    zzzquil liquid warming berry flavor sleep-aid  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    zzzquil nighttime liquid sleep-aid twin pack  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    zzzquil vanilla cherry nighttime liquid sleep aid
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 28632 columns]

# %%
freq_items = apriori(encoded_df, min_support=0.01, use_colnames=True)

# %%
freq_items
# Out:
#      support                                      itemsets
# 0   0.011958                      (100% raw coconut water)
# 1   0.019435                      (100% whole wheat bread)
# 2   0.011859                         (2% reduced fat milk)
# 3   0.027230                    (apple honeycrisp organic)
# 4   0.120913                      (bag of organic bananas)
# ..       ...                                           ...
# 72  0.017980                (organic strawberries, banana)
# 73  0.010107                  (organic whole milk, banana)
# 74  0.013478                        (banana, strawberries)
# 75  0.012116  (organic baby spinach, organic strawberries)
# 76  0.010510   (organic raspberries, organic strawberries)
#
# [77 rows x 2 columns]

# %%
rules = association_rules(freq_items, metric='confidence', min_threshold=0.01)
rules
# Out:
#                  antecedents               consequents  antecedent support  \
# 0   (bag of organic bananas)    (organic baby spinach)            0.120913
# 1     (organic baby spinach)  (bag of organic bananas)            0.077229
# 2   (bag of organic bananas)     (organic raspberries)            0.120913
# 3      (organic raspberries)  (bag of organic bananas)            0.043151
# 4   (bag of organic bananas)    (organic strawberries)            0.120913
# 5     (organic strawberries)  (bag of organic bananas)            0.084283
# 6                    (limes)                  (banana)            0.044859
# 7                   (banana)                   (limes)            0.151702
# 8     (organic baby spinach)                  (banana)            0.077229
# 9                   (banana)    (organic baby spinach)            0.151702
# 10      (organic fuji apple)                  (banana)            0.028569
# 11                  (banana)      (organic fuji apple)            0.151702
# 12    (organic strawberries)                  (banana)            0.084283
# 13                  (banana)    (organic strawberries)            0.151702
# 14      (organic whole milk)                  (banana)            0.043936
# 15                  (banana)      (organic whole milk)            0.151702
# 16                  (banana)            (strawberries)            0.151702
# 17            (strawberries)                  (banana)            0.045893
# 18    (organic baby spinach)    (organic strawberries)            0.077229
# 19    (organic strawberries)    (organic baby spinach)            0.084283
# 20     (organic raspberries)    (organic strawberries)            0.043151
# 21    (organic strawberries)     (organic raspberries)            0.084283
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.077229  0.015962    0.132009  1.709320  0.006624    1.063112
# 1             0.120913  0.015962    0.206678  1.709320  0.006624    1.108110
# 2             0.043151  0.012590    0.104127  2.413109  0.007373    1.068064
# 3             0.120913  0.012590    0.291776  2.413109  0.007373    1.241255
# 4             0.084283  0.019538    0.161586  1.917198  0.009347    1.092203
# 5             0.120913  0.019538    0.231814  1.917198  0.009347    1.144367
# 6             0.151702  0.010121    0.225615  1.487225  0.003316    1.095447
# 7             0.044859  0.010121    0.066715  1.487225  0.003316    1.023419
# 8             0.151702  0.016621    0.215215  1.418667  0.004905    1.080930
# 9             0.077229  0.016621    0.109563  1.418667  0.004905    1.036312
# 10            0.151702  0.010903    0.381636  2.515695  0.006569    1.371842
# 11            0.028569  0.010903    0.071871  2.515695  0.006569    1.046655
# 12            0.151702  0.017980    0.213333  1.406267  0.005194    1.078345
# 13            0.084283  0.017980    0.118524  1.406267  0.005194    1.038845
# 14            0.151702  0.010107    0.230040  1.516393  0.003442    1.101743
# 15            0.043936  0.010107    0.066625  1.516393  0.003442    1.024308
# 16            0.045893  0.013478    0.088848  1.935959  0.006516    1.047143
# 17            0.151702  0.013478    0.293689  1.935959  0.006516    1.201026
# 18            0.084283  0.012116    0.156877  1.861327  0.005606    1.086102
# 19            0.077229  0.012116    0.143749  1.861327  0.005606    1.077687
# 20            0.084283  0.010510    0.243568  2.889901  0.006873    1.210575
# 21            0.043151  0.010510    0.124701  2.889901  0.006873    1.093169

# %% [markdown]
# ### Testing FP Growth

# %%
freq_items_fp = fpgrowth(encoded_df, min_support=0.01, use_colnames=True)

# %%
freq_items_fp
# Out:
#      support                                        itemsets
# 0   0.023524                                       (carrots)
# 1   0.021703                         (michigan organic kale)
# 2   0.077229                          (organic baby spinach)
# 3   0.015576                        (unsweetened almondmilk)
# 4   0.120913                        (bag of organic bananas)
# ..       ...                                             ...
# 72  0.019538  (bag of organic bananas, organic strawberries)
# 73  0.010107                    (organic whole milk, banana)
# 74  0.010903                    (organic fuji apple, banana)
# 75  0.013478                          (banana, strawberries)
# 76  0.010121                                 (limes, banana)
#
# [77 rows x 2 columns]

# %%
rules_fp = association_rules(freq_items_fp, metric='confidence', min_threshold=0.2)
rules_fp
# Out:
#               antecedents               consequents  antecedent support  \
# 0  (organic baby spinach)                  (banana)            0.077229
# 1  (organic baby spinach)  (bag of organic bananas)            0.077229
# 2   (organic raspberries)  (bag of organic bananas)            0.043151
# 3   (organic raspberries)    (organic strawberries)            0.043151
# 4  (organic strawberries)                  (banana)            0.084283
# 5  (organic strawberries)  (bag of organic bananas)            0.084283
# 6    (organic whole milk)                  (banana)            0.043936
# 7    (organic fuji apple)                  (banana)            0.028569
# 8          (strawberries)                  (banana)            0.045893
# 9                 (limes)                  (banana)            0.044859
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.151702  0.016621    0.215215  1.418667  0.004905    1.080930
# 1            0.120913  0.015962    0.206678  1.709320  0.006624    1.108110
# 2            0.120913  0.012590    0.291776  2.413109  0.007373    1.241255
# 3            0.084283  0.010510    0.243568  2.889901  0.006873    1.210575
# 4            0.151702  0.017980    0.213333  1.406267  0.005194    1.078345
# 5            0.120913  0.019538    0.231814  1.917198  0.009347    1.144367
# 6            0.151702  0.010107    0.230040  1.516393  0.003442    1.101743
# 7            0.151702  0.010903    0.381636  2.515695  0.006569    1.371842
# 8            0.151702  0.013478    0.293689  1.935959  0.006516    1.201026
# 9            0.151702  0.010121    0.225615  1.487225  0.003316    1.095447

# %% [markdown]
# #### Compute element frequency

# %% [markdown]
# ## Could we try tro look for associations between aisles?

# %%
aisle_df = order_set[['order_id','aisle']]
aisle_df = aisle_df.loc[aisles_df['orders']
# Out:
#          order_id                   aisle
# 0               2        fresh vegetables
# 1               2       spices seasonings
# 2               2      baking ingredients
# 3               2        fresh vegetables
# 4               2                 spreads
# ...           ...                     ...
# 1999995    319927                  coffee
# 1999996    319928  nuts seeds dried fruit
# 1999997    319928       baby food formula
# 1999998    319928            fresh fruits
# 1999999    319928                 spreads
#
# [2000000 rows x 2 columns]

# %%
aisle_lst = []

for v,num in enumerate(order_num):
    aisle = aisle_df.loc[aisle_df['order_id'] == num]['aisle'].tolist()
    aisle_lst.append(aisle)

# %%
aisle_df_fp = pd.DataFrame(order_num, columns = ['num_order'])
aisle_df_fp['aisles'] = [lst for lst in aisle_lst]
aisle_df_fp.head()
# Out:
#    num_order                                             aisles
# 0          2  [fresh vegetables, spices seasonings, baking i...
# 1          3  [soy lactosefree, soy lactosefree, bread, pack...
# 2          4  [refrigerated, breakfast bars pastries, cracke...
# 3          5  [packaged vegetables fruits, packaged produce,...
# 4          6                                          [laundry]

# %%
te_ary_2 = te.fit(aisle_lst).transform(aisle_lst)
te_ary_2
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
aisle_enc = pd.DataFrame(te_ary_2, columns = te.columns_)
aisle_enc.head()
# Out:
#    air fresheners candles  asian foods  baby accessories  baby bath body care  \
# 0                   False        False             False                False
# 1                   False        False             False                False
# 2                   False        False             False                False
# 3                   False        False             False                False
# 4                   False        False             False                False
#
#    baby food formula  bakery desserts  baking ingredients  \
# 0              False            False                True
# 1              False            False               False
# 2              False            False               False
# 3              False            False               False
# 4              False            False               False
#
#    baking supplies decor  beauty  beers coolers  ...  spreads    tea  \
# 0                  False   False          False  ...     True  False
# 1                  False   False          False  ...    False  False
# 2                  False   False          False  ...    False  False
# 3                  False   False          False  ...     True  False
# 4                  False   False          False  ...    False  False
#
#    tofu meat alternatives  tortillas flat bread  trail mix snack mix  \
# 0                   False                 False                False
# 1                   False                 False                False
# 2                   False                 False                False
# 3                   False                 False                False
# 4                   False                 False                False
#
#    trash bags liners  vitamins supplements  water seltzer sparkling water  \
# 0              False                 False                          False
# 1              False                 False                          False
# 2              False                 False                          False
# 3              False                 False                           True
# 4              False                 False                          False
#
#    white wines  yogurt
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
#
# [5 rows x 134 columns]

# %% [markdown]
# #### Testing FP Growth

# %%
freq_items_3 = fpgrowth(aisle_enc, min_support=0.1, use_colnames=True)
freq_items_3
# Out:
#      support                                           itemsets
# 0   0.362219                                 (fresh vegetables)
# 1   0.277919                       (packaged vegetables fruits)
# 2   0.127939                                            (bread)
# 3   0.111089                                  (soy lactosefree)
# 4   0.482090                                     (fresh fruits)
# 5   0.203337                                             (milk)
# 6   0.178420                                  (packaged cheese)
# 7   0.134702                    (water seltzer sparkling water)
# 8   0.197107                                           (yogurt)
# 9   0.123724                                   (chips pretzels)
# 10  0.101057                                   (frozen produce)
# 11  0.101464                                             (eggs)
# 12  0.222670                   (fresh fruits, fresh vegetables)
# 13  0.179335         (fresh fruits, packaged vegetables fruits)
# 14  0.149564     (fresh vegetables, packaged vegetables fruits)
# 15  0.105474  (fresh fruits, fresh vegetables, packaged vege...
# 16  0.119082                               (fresh fruits, milk)
# 17  0.104343                    (fresh fruits, packaged cheese)
# 18  0.124506                             (fresh fruits, yogurt)

# %%
rules_fq3 = association_rules(freq_items_3, metric='confidence', min_threshold=0.3)
rules_fq3
# Out:
#                                        antecedents  \
# 0                                   (fresh fruits)
# 1                               (fresh vegetables)
# 2                                   (fresh fruits)
# 3                     (packaged vegetables fruits)
# 4                               (fresh vegetables)
# 5                     (packaged vegetables fruits)
# 6                 (fresh fruits, fresh vegetables)
# 7       (fresh fruits, packaged vegetables fruits)
# 8   (packaged vegetables fruits, fresh vegetables)
# 9                     (packaged vegetables fruits)
# 10                                          (milk)
# 11                               (packaged cheese)
# 12                                        (yogurt)
#
#                          consequents  antecedent support  consequent support  \
# 0                 (fresh vegetables)            0.482090            0.362219
# 1                     (fresh fruits)            0.362219            0.482090
# 2       (packaged vegetables fruits)            0.482090            0.277919
# 3                     (fresh fruits)            0.277919            0.482090
# 4       (packaged vegetables fruits)            0.362219            0.277919
# 5                 (fresh vegetables)            0.277919            0.362219
# 6       (packaged vegetables fruits)            0.222670            0.277919
# 7                 (fresh vegetables)            0.179335            0.362219
# 8                     (fresh fruits)            0.149564            0.482090
# 9   (fresh fruits, fresh vegetables)            0.277919            0.222670
# 10                    (fresh fruits)            0.203337            0.482090
# 11                    (fresh fruits)            0.178420            0.482090
# 12                    (fresh fruits)            0.197107            0.482090
#
#      support  confidence      lift  leverage  conviction
# 0   0.222670    0.461885  1.275155  0.048048    1.185214
# 1   0.222670    0.614739  1.275155  0.048048    1.344310
# 2   0.179335    0.371995  1.338501  0.045353    1.149801
# 3   0.179335    0.645277  1.338501  0.045353    1.460043
# 4   0.149564    0.412910  1.485718  0.048896    1.229931
# 5   0.149564    0.538155  1.485718  0.048896    1.380943
# 6   0.105474    0.473677  1.704370  0.043589    1.371935
# 7   0.105474    0.588138  1.623709  0.040515    1.548531
# 8   0.105474    0.705209  1.462818  0.033371    1.756875
# 9   0.105474    0.379512  1.704370  0.043589    1.252772
# 10  0.119082    0.585637  1.214789  0.021055    1.249897
# 11  0.104343    0.584819  1.213091  0.018329    1.247431
# 12  0.124506    0.631667  1.310269  0.029483    1.406094

# %% [markdown]
# # How can we visualize these rules?
