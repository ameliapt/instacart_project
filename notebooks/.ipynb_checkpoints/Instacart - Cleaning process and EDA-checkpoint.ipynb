# %% [markdown]
# # Instacart - PROJECT NAME
#
# ## Data cleaning process
#
# Libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 1
#
# Load datasets and preprocess data. Instacart customer purchase information is divided into 6 datasets:
#
# 1. Aisles
# 2. Departments
# 3. Order_products__prior (This table includes training orders and indicates whether a product in an order is a reorder or not (through the reordered variable)
# 5. Orders
# 6. Products
#
# I have perfomed some join operations with MYSQL to merge Aisles, Departments and Products files. The resulting dataset is named info.csv.

# %%
info = pd.read_csv('../data/info.csv')
print('-- NULL VALUES --')
print(info.isna().sum(), '\n')
print('-- INFO --')
info.info()
print()
print('-- SUMMARY --')
display(round(info.describe().T,2))
display(round(info.describe(include=object).T,2))
print()
print('-- FIRST 5 ROWS --')
info.head()
# Out:
# -- NULL VALUES --
# product_id       21
# product_name      0
# department_id     0
# aisle_id         21
# aisle            21
# department        0
# dtype: int64
#
# -- INFO --
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32994 entries, 0 to 32993
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     32973 non-null  float64
#  1   product_name   32994 non-null  object
#  2   department_id  32994 non-null  int64
#  3   aisle_id       32973 non-null  float64
#  4   aisle          32973 non-null  object
#  5   department     32994 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.5+ MB
#
# -- SUMMARY --
#                  count      mean      std  min     25%      50%      75%  \
# product_id     32973.0  16487.79  9518.91  1.0  8245.0  16488.0  24731.0
# department_id  32994.0     11.73     5.84  1.0     7.0     13.0     17.0
# aisle_id       32973.0     67.65    38.35  1.0    34.0     69.0    100.0
#
#                    max
# product_id     32974.0
# department_id     21.0
# aisle_id         134.0
#               count unique                    top  freq
# product_name  32994  32994  Total 0% Peach Yogurt     1
# aisle         32973    134                missing   812
# department    32994     21          personal care  4382
# -- FIRST 5 ROWS --
#    product_id                               product_name  department_id  \
# 0      3647.0               Soft Dinner 6 Ct White Rolls              1
# 1      3646.0   Eggo Breakfast Sandwich Bacon Egg Cheese              1
# 2      3645.0                            Creamed Spinach              1
# 3      3628.0               Gluten Free Paleo Fettuccine              1
# 4      3608.0  Brie & Raspberry Bake & Serve Fillo Rolls              1
#
#    aisle_id                    aisle department
# 0      58.0     frozen breads doughs     frozen
# 1      52.0         frozen breakfast     frozen
# 2     116.0           frozen produce     frozen
# 3      38.0             frozen meals     frozen
# 4     129.0  frozen appetizers sides     frozen

# %%
info['product_id'].nunique()
# Out:
# 32973

# %% [markdown]
# *Cols meaning*
# * order_dow: Day Of Week
# * eval_set: which evaluation set this order belongs in (see train and prior dataset described below)
# * order_number: the order sequence number for this user (1 = first, n = nth)
# * days_since_prior: days since the last order, capped at 30 (with NAs for order_number = 1)
# * add_to_cart_order: order in which each product was added to cart
# * reordered: 1 if this product has been ordered by this user in the past, 0 otherwise
# * “prior”: orders prior to that users most recent order

# %% [markdown]
# #### Merging orders files.

# %%
orders = pd.read_csv('../data/orders.csv')
print('-- NULL VALUES --')
print(orders.isna().sum(), '\n')
print('-- INFO --')
orders.info()
print()
print('-- SUMMARY --')
display(round(orders.describe().T,2))
display(round(orders.describe(include=object).T,2))
print()
print('-- FIRST 5 ROWS --')
orders.head()
# Out:
# -- NULL VALUES --
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64
#
# -- INFO --
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
#
# -- SUMMARY --
#                             count        mean        std  min       25%  \
# order_id                3421083.0  1710542.00  987581.74  1.0  855271.5
# user_id                 3421083.0   102978.21   59533.72  1.0   51394.0
# order_number            3421083.0       17.15      17.73  1.0       5.0
# order_dow               3421083.0        2.78       2.05  0.0       1.0
# order_hour_of_day       3421083.0       13.45       4.23  0.0      10.0
# days_since_prior_order  3214874.0       11.11       9.21  0.0       4.0
#
#                               50%        75%        max
# order_id                1710542.0  2565812.5  3421083.0
# user_id                  102689.0   154385.0   206209.0
# order_number                 11.0       23.0      100.0
# order_dow                     3.0        5.0        6.0
# order_hour_of_day            13.0       16.0       23.0
# days_since_prior_order        7.0       15.0       30.0
#             count unique    top     freq
# eval_set  3421083      3  prior  3214874
# -- FIRST 5 ROWS --
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_products_prior = pd.read_csv('../data/order_products__prior.csv')
print('-- NULL VALUES --')
print(order_products_prior.isna().sum(), '\n')
print('-- INFO --')
order_products_prior.info()
print()
print('-- SUMMARY --')
display(round(order_products_prior.describe().T,2))
print()
print('-- FIRST 5 ROWS --')
display(order_products_prior.head())
# Out:
# -- NULL VALUES --
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64
#
# -- INFO --
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB
#
# -- SUMMARY --
#                         count        mean        std  min       25%  \
# order_id           32434489.0  1710748.52  987300.70  2.0  855943.0
# product_id         32434489.0    25576.34   14096.69  1.0   13530.0
# add_to_cart_order  32434489.0        8.35       7.13  1.0       3.0
# reordered          32434489.0        0.59       0.49  0.0       0.0
#
#                          50%        75%        max
# order_id           1711048.0  2565514.0  3421083.0
# product_id           25256.0    37935.0    49688.0
# add_to_cart_order        6.0       11.0      145.0
# reordered                1.0        1.0        1.0
# -- FIRST 5 ROWS --
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
orders_full = pd.merge(orders, order_products_prior, on = 'order_id')
print('-- NULL VALUES --')
print(orders_full.isna().sum(), '\n')
print('-- INFO --')
orders_full.info()
print()
print('-- SUMMARY --')
# display(round(orders_full.describe().T,2))
print()
print('-- FIRST 5 ROWS --')
display(orders_full.head())
# Out:
# -- NULL VALUES --
# order_id                        0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# dtype: int64
#
# -- INFO --
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 2.7+ GB
#
# -- SUMMARY --
#
# -- FIRST 5 ROWS --
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %% [markdown]
# ### Merging info file and orders file.

# %%
info_orders = pd.merge(orders_full, info, on = 'product_id')
print('-- NULL VALUES --')
print(info_orders.isna().sum(), '\n')
print('-- INFO --')
info_orders.info()
print()
print('-- SUMMARY --')
display(round(info_orders.describe().T,2))
print()
print('-- FIRST 5 ROWS --')
display(info_orders.head())
# Out:
# -- NULL VALUES --
# order_id                        0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    1368530
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                    0
# department_id                   0
# aisle_id                        0
# aisle                           0
# department                      0
# dtype: int64
#
# -- INFO --
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21407642 entries, 0 to 21407641
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  department_id           int64
#  12  aisle_id                float64
#  13  aisle                   object
#  14  department              object
# dtypes: float64(2), int64(9), object(4)
# memory usage: 2.6+ GB
#
# -- SUMMARY --
#                              count        mean        std  min       25%  \
# order_id                21407642.0  1710875.63  987181.55  2.0  856208.0
# user_id                 21407642.0   102934.86   59470.12  1.0   51404.0
# order_number            21407642.0       17.18      17.56  1.0       5.0
# order_dow               21407642.0        2.74       2.09  0.0       1.0
# order_hour_of_day       21407642.0       13.42       4.25  0.0      10.0
# days_since_prior_order  20039112.0       11.09       8.77  0.0       5.0
# product_id              21407642.0    17274.77    9285.12  1.0    9076.0
# add_to_cart_order       21407642.0        8.29       7.11  1.0       3.0
# reordered               21407642.0        0.59       0.49  0.0       0.0
# department_id           21407642.0        9.94       6.29  1.0       4.0
# aisle_id                21407642.0       70.94      38.13  1.0      31.0
#
#                               50%        75%        max
# order_id                1711365.0  2565488.0  3421083.0
# user_id                  102610.0   154385.0   206209.0
# order_number                 11.0       24.0       99.0
# order_dow                     3.0        5.0        6.0
# order_hour_of_day            13.0       16.0       23.0
# days_since_prior_order        8.0       15.0       30.0
# product_id                18023.0    24964.0    32974.0
# add_to_cart_order             6.0       11.0      145.0
# reordered                     1.0        1.0        1.0
# department_id                 9.0       16.0       21.0
# aisle_id                     83.0      107.0      134.0
# -- FIRST 5 ROWS --
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  department_id  aisle_id        aisle department
# 0         Soda              7      77.0  soft drinks  beverages
# 1         Soda              7      77.0  soft drinks  beverages
# 2         Soda              7      77.0  soft drinks  beverages
# 3         Soda              7      77.0  soft drinks  beverages
# 4         Soda              7      77.0  soft drinks  beverages

# %%
sorted_instacart = info_orders.sort_values(by='order_id').reset_index(drop=True)
sorted_instacart.tail()
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 21407637   3421083    25247    prior            24          2
# 21407638   3421083    25247    prior            24          2
# 21407639   3421083    25247    prior            24          2
# 21407640   3421083    25247    prior            24          2
# 21407641   3421083    25247    prior            24          2
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 21407637                  6                    21.0        7854
# 21407638                  6                    21.0        5020
# 21407639                  6                    21.0       18176
# 21407640                  6                    21.0        4600
# 21407641                  6                    21.0       11352
#
#           add_to_cart_order  reordered  \
# 21407637                  1          0
# 21407638                 10          1
# 21407639                  4          1
# 21407640                  8          0
# 21407641                  7          0
#
#                                                product_name  department_id  \
# 21407637                          Freeze Dried Mango Slices             19
# 21407638  Organic  Sweet & Salty Peanut Pretzel Granola ...             19
# 21407639            Organic Strawberry Yogurt & Fruit Snack             18
# 21407640                    All Natural French Toast Sticks              1
# 21407641       Organic Mini Sandwich Crackers Peanut Butter             19
#
#           aisle_id                   aisle department
# 21407637     117.0  nuts seeds dried fruit     snacks
# 21407638       3.0     energy granola bars     snacks
# 21407639      92.0       baby food formula     babies
# 21407640      52.0        frozen breakfast     frozen
# 21407641      78.0                crackers     snacks

# %%
sorted_instacart = sorted_instacart.drop('eval_set', axis = 1)

# %%
# sorted_instacart.to_csv('../data/instacart.csv')

# %% [markdown]
# ## EDA

# %% [markdown]
# * Time period
# * How many products?
# * Boxplot distribution of products

# %% [markdown]
# #### How many users and orders?

# %%
print('Number of users:', sorted_instacart['user_id'].nunique())
print('Total number of orders:', sorted_instacart['order_id'].nunique())

# %% [markdown]
# #### How many purchases (orders) by user?

# %%
order_by_user = sorted_instacart.groupby('user_id')['order_number'].max()
order_by_user_df = pd.Series.to_frame(order_by_user) 
order_by_user_df.head()

# %%
print('Max number of orders by user:', max(order_by_user_df['order_number']))
print('Min number of orders by user:', min(order_by_user_df['order_number']))
print('Median number of orders by user:', round(np.median(order_by_user_df['order_number'])))
print('Mean number of orders by user:', round(np.mean(order_by_user_df['order_number'])))

# %%
fig, ax = plt.subplots(figsize = (40,25), dpi = 100) 
sns.countplot(x=order_by_user_df['order_number'])
ax.set(xlabel='Number of orders', ylabel='Users')
plt.show()

# %% [markdown]
# #### Most 'popular' day

# %%
orders_day = sorted_instacart.groupby('order_id')['order_dow'].max()
orders_day

# %%
fig, ax = plt.subplots(figsize = (40,25), dpi = 100) 
sns.countplot(x=orders_day.values)
ax.set(xlabel='Days of the Week', ylabel='Number of orders')
plt.show()

# %% [markdown]
# #### Most 'popular' hour

# %%
orders_hour = sorted_instacart.groupby('order_id')['order_hour_of_day'].max()
orders_hour

# %%
fig, ax = plt.subplots(figsize = (40,25), dpi = 100) 
sns.countplot(x=orders_hour.values)
ax.set(xlabel='Hours of the day', ylabel='Number of orders')
plt.show()

# %% [markdown]
# #### How many days goes by between orders?

# %%
reorders_time = sorted_instacart.groupby('order_id')['days_since_prior_order'].max()
reorders_time

# %%
fig, ax = plt.subplots(figsize = (40,25), dpi = 100) 
sns.countplot(x=reorders_time.values)
ax.set(xlabel='Days between orders', ylabel='Number of orders')
plt.show()

# %% [markdown]
# #### Most ordered products

# %%
top_20_ordered_prod = sorted_instacart[['product_name', 'aisle']].value_counts().head(20)
pd.Series.to_frame(top_20_ordered_prod)

# %% [markdown]
# #### Most reordered products

# %%
reordered_prod = sorted_instacart.loc[sorted_instacart['reordered'] == 1]
top20_products = reordered_prod[['product_name','aisle']].value_counts().head(200)
pd.Series.to_frame(top20_products)

# %% [markdown]
# #### Most visited 'aisles'

# %%
top10_aisles = sorted_instacart['aisle'].value_counts().head(10)
top10_aisles

# %%
labels = ['fresh fruits', 'fresh vegetables', 'packaged vegetables fruits', 'yogurt', 'milk', 'packaged cheese',
         'water seltzen sparkling water', 'chips pretzels', 'bread', 'soy lactosefree']
ax, fig = plt.subplots(figsize=(15,10))
plt.pie(top10_aisles, labels = labels, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Time period: one year

# %% [markdown]
# Could we infere the period time? If a customer has ordered 12 times with a frequency of XX days, we could know the period of time for our data. Let's compute the sum of days for each customer to check the maximum value of days_since_prior_order and get the time range.

# %%
orders = pd.read_csv('../data/orders.csv')
orders.head()

# %%
orders.loc[orders['days_since_prior_order'] == 0]

# %%
sum_days_orders = orders.groupby('user_id')['days_since_prior_order'].sum()
max(sum_days_orders)
